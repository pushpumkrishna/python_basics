# %%
# Importing libraries

# for data manipulation
import pandas as pd
import numpy as np

# for data visualization  
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing training data

train = pd.read_csv("E:/Data Science/Datasets/Loan Default Prediction Competition/train.csv", index_col = 'Id')

train.dropna(how = 'all')

# Printing transpose of dataset to view all columns
train.T
# Out:
# Id                                          0                   1     \
# Home Ownership                          Own Home            Own Home
# Annual Income                             482087         1.02549e+06
# Years in current job                         NaN           10+ years
# Tax Liens                                      0                   0
# Number of Open Accounts                       11                  15
# Years of Credit History                     26.3                15.3
# Maximum Open Credit                       685960         1.18173e+06
# Number of Credit Problems                      1                   0
# Months since last delinquent                 NaN                 NaN
# Bankruptcies                                   1                   0
# Purpose                       debt consolidation  debt consolidation
# Term                                  Short Term           Long Term
# Current Loan Amount                        1e+08              264968
# Current Credit Balance                     47386              394972
# Monthly Debt                                7914               18373
# Credit Score                                 749                 737
# Credit Default                                 0                   1
#
# Id                                          2                   3     \
# Home Ownership                     Home Mortgage            Own Home
# Annual Income                             751412              805068
# Years in current job                     8 years             6 years
# Tax Liens                                      0                   0
# Number of Open Accounts                       11                   8
# Years of Credit History                       35                22.5
# Maximum Open Credit                  1.18243e+06              147400
# Number of Credit Problems                      0                   1
# Months since last delinquent                 NaN                 NaN
# Bankruptcies                                   0                   1
# Purpose                       debt consolidation  debt consolidation
# Term                                  Short Term          Short Term
# Current Loan Amount                        1e+08              121396
# Current Credit Balance                    308389               95855
# Monthly Debt                               13651               11338
# Credit Score                                 742                 694
# Credit Default                                 0                   0
#
# Id                                          4          5     \
# Home Ownership                              Rent       Rent
# Annual Income                             776264        NaN
# Years in current job                     8 years    7 years
# Tax Liens                                      0          0
# Number of Open Accounts                       13         12
# Years of Credit History                     13.6       14.6
# Maximum Open Credit                       385836     366784
# Number of Credit Problems                      1          0
# Months since last delinquent                 NaN        NaN
# Bankruptcies                                   0          0
# Purpose                       debt consolidation      other
# Term                                  Short Term  Long Term
# Current Loan Amount                       125840     337304
# Current Credit Balance                     93309     165680
# Monthly Debt                                7180      18692
# Credit Score                                 719        NaN
# Credit Default                                 0          1
#
# Id                                         6            7     \
# Home Ownership                    Home Mortgage         Rent
# Annual Income                       1.51111e+06  1.04006e+06
# Years in current job                  10+ years    10+ years
# Tax Liens                                     0            0
# Number of Open Accounts                       9           13
# Years of Credit History                    20.3           12
# Maximum Open Credit                      388124       330374
# Number of Credit Problems                     0            0
# Months since last delinquent                 73           18
# Bankruptcies                                  0            0
# Purpose                       home improvements        other
# Term                                 Short Term   Short Term
# Current Loan Amount                       1e+08       250888
# Current Credit Balance                    51623        89015
# Monthly Debt                               2317        19761
# Credit Score                                745          705
# Credit Default                                0            1
#
# Id                                         8                   9     ...  \
# Home Ownership                    Home Mortgage       Home Mortgage  ...
# Annual Income                               NaN                 NaN  ...
# Years in current job                    5 years              1 year  ...
# Tax Liens                                     0                   0  ...
# Number of Open Accounts                      17                  10  ...
# Years of Credit History                    15.7                24.6  ...
# Maximum Open Credit                           0              511302  ...
# Number of Credit Problems                     1                   0  ...
# Months since last delinquent                NaN                   6  ...
# Bankruptcies                                  1                   0  ...
# Purpose                       home improvements  debt consolidation  ...
# Term                                 Short Term           Long Term  ...
# Current Loan Amount                      129734              572880  ...
# Current Credit Balance                       19              205333  ...
# Monthly Debt                                 17               17613  ...
# Credit Score                                NaN                 NaN  ...
# Credit Default                                0                   1  ...
#
# Id                                          7490                7491  \
# Home Ownership                          Own Home       Home Mortgage
# Annual Income                          1.368e+06         2.83318e+06
# Years in current job                   10+ years             6 years
# Tax Liens                                      0                   0
# Number of Open Accounts                       20                  18
# Years of Credit History                     26.7                21.3
# Maximum Open Credit                       897842              280170
# Number of Credit Problems                      0                   0
# Months since last delinquent                  69                   6
# Bankruptcies                                   0                   0
# Purpose                       debt consolidation  debt consolidation
# Term                                  Short Term          Short Term
# Current Loan Amount                       683650              437404
# Current Credit Balance                    517199              108889
# Monthly Debt                               29868               61150
# Credit Score                                 688                 704
# Credit Default                                 1                   0
#
# Id                                          7492                7493  \
# Home Ownership                     Home Mortgage                Rent
# Annual Income                                NaN         1.25761e+06
# Years in current job                   10+ years             8 years
# Tax Liens                                      0                   0
# Number of Open Accounts                       10                  14
# Years of Credit History                     13.3                16.5
# Maximum Open Credit                       423984              821480
# Number of Credit Problems                      0                   0
# Months since last delinquent                 NaN                  58
# Bankruptcies                                   0                   0
# Purpose                       debt consolidation  debt consolidation
# Term                                  Short Term           Long Term
# Current Loan Amount                       332948              448052
# Current Credit Balance                    161481              167428
# Monthly Debt                               20966               27562
# Credit Score                                 NaN                 676
# Credit Default                                 0                   1
#
# Id                                          7494        7495  \
# Home Ownership                          Own Home        Rent
# Annual Income                                NaN      402192
# Years in current job                    < 1 year    < 1 year
# Tax Liens                                      0           0
# Number of Open Accounts                        7           3
# Years of Credit History                      8.2         8.5
# Maximum Open Credit                       301554      107866
# Number of Credit Problems                      0           0
# Months since last delinquent                 NaN         NaN
# Bankruptcies                                   0           0
# Purpose                       debt consolidation       other
# Term                                  Short Term  Short Term
# Current Loan Amount                       290400      129360
# Current Credit Balance                    210938       73492
# Monthly Debt                                5070        1900
# Credit Score                                 NaN         697
# Credit Default                                 0           0
#
# Id                                          7496         7497  \
# Home Ownership                     Home Mortgage         Rent
# Annual Income                        1.53398e+06  1.87891e+06
# Years in current job                      1 year      6 years
# Tax Liens                                      0            0
# Number of Open Accounts                       10           12
# Years of Credit History                     26.5         32.1
# Maximum Open Credit                       686312  1.77892e+06
# Number of Credit Problems                      0            0
# Months since last delinquent                  43          NaN
# Bankruptcies                                   0            0
# Purpose                       debt consolidation    buy a car
# Term                                   Long Term   Short Term
# Current Loan Amount                       444048        1e+08
# Current Credit Balance                    456399       477812
# Monthly Debt                               12783        12479
# Credit Score                                7410          748
# Credit Default                                 1            0
#
# Id                                          7498                7499
# Home Ownership                     Home Mortgage                Rent
# Annual Income                                NaN                 NaN
# Years in current job                         NaN             4 years
# Tax Liens                                      0                   0
# Number of Open Accounts                       21                   8
# Years of Credit History                     26.5                 9.4
# Maximum Open Credit                  1.14125e+06              480832
# Number of Credit Problems                      0                   0
# Months since last delinquent                 NaN                 NaN
# Bankruptcies                                   0                   0
# Purpose                       debt consolidation  debt consolidation
# Term                                  Short Term          Short Term
# Current Loan Amount                       615274               26928
# Current Credit Balance                    476064              288192
# Monthly Debt                               37118                9061
# Credit Score                                 NaN                 NaN
# Credit Default                                 0                   0
#
# [17 rows x 7500 columns]

# %%
# Importing test data

test = pd.read_csv("E:/Data Science/Datasets/Loan Default Prediction Competition/test.csv", index_col = 'Id')

test.dropna(how = 'all')

# Printing transpose of dataset to view all columns
test.T
# Out:
# Id                                          7500                  7501  \
# Home Ownership                              Rent                  Rent
# Annual Income                                NaN                231838
# Years in current job                     4 years                1 year
# Tax Liens                                      0                     0
# Number of Open Accounts                        9                     6
# Years of Credit History                     12.5                  32.7
# Maximum Open Credit                       220968                 55946
# Number of Credit Problems                      0                     0
# Months since last delinquent                  70                     8
# Bankruptcies                                   0                     0
# Purpose                       debt consolidation  educational expenses
# Term                                  Short Term            Short Term
# Current Loan Amount                       162470                 78298
# Current Credit Balance                    105906                 46037
# Monthly Debt                                6813                  2318
# Credit Score                                 NaN                   699
#
# Id                                          7502                7503  \
# Home Ownership                     Home Mortgage       Home Mortgage
# Annual Income                        1.15254e+06         1.22031e+06
# Years in current job                     3 years           10+ years
# Tax Liens                                      0                   0
# Number of Open Accounts                       10                  16
# Years of Credit History                     13.7                  17
# Maximum Open Credit                       204600              456302
# Number of Credit Problems                      0                   0
# Months since last delinquent                 NaN                  70
# Bankruptcies                                   0                   0
# Purpose                       debt consolidation  debt consolidation
# Term                                  Short Term          Short Term
# Current Loan Amount                       200178              217382
# Current Credit Balance                    146490              213199
# Monthly Debt                               18729               27559
# Credit Score                                7260                 739
#
# Id                                          7504                7505  \
# Home Ownership                     Home Mortgage       Home Mortgage
# Annual Income                        2.34095e+06              922583
# Years in current job                     6 years             5 years
# Tax Liens                                      0                   0
# Number of Open Accounts                       11                  26
# Years of Credit History                     23.6                17.5
# Maximum Open Credit                  1.20727e+06              713174
# Number of Credit Problems                      0                   0
# Months since last delinquent                 NaN                  41
# Bankruptcies                                   0                   0
# Purpose                       debt consolidation  debt consolidation
# Term                                   Long Term          Short Term
# Current Loan Amount                       777634               94028
# Current Credit Balance                    425391              135508
# Monthly Debt                               42605               11148
# Credit Score                                 706                 679
#
# Id                                         7506                7507  \
# Home Ownership                    Home Mortgage                Rent
# Annual Income                       1.23331e+06         1.21587e+06
# Years in current job                    3 years             3 years
# Tax Liens                                     0                   0
# Number of Open Accounts                       7                  13
# Years of Credit History                      22                12.2
# Maximum Open Credit                      376420              195888
# Number of Credit Problems                     0                   0
# Months since last delinquent                 43                  19
# Bankruptcies                                  0                   0
# Purpose                       home improvements  debt consolidation
# Term                                 Short Term          Short Term
# Current Loan Amount                      454388              407726
# Current Credit Balance                   292904              120099
# Monthly Debt                               8181                7599
# Credit Score                                685                 701
#
# Id                                      7508                7509  ...  \
# Home Ownership                          Rent       Home Mortgage  ...
# Annual Income                            NaN         2.14044e+06  ...
# Years in current job                 5 years           10+ years  ...
# Tax Liens                                  0                   1  ...
# Number of Open Accounts                    8                  15  ...
# Years of Credit History                  9.1                16.7  ...
# Maximum Open Credit                   370524              867680  ...
# Number of Credit Problems                  0                   1  ...
# Months since last delinquent             NaN                   9  ...
# Bankruptcies                               0                   0  ...
# Purpose                       major purchase  debt consolidation  ...
# Term                              Short Term          Short Term  ...
# Current Loan Amount                   131956              391336  ...
# Current Credit Balance                237747              294500  ...
# Monthly Debt                           10112               18372  ...
# Credit Score                             NaN                 745  ...
#
# Id                                          9990        9991           9992  \
# Home Ownership                     Home Mortgage        Rent  Home Mortgage
# Annual Income                        1.49446e+06      916199         750500
# Years in current job                   10+ years     2 years        3 years
# Tax Liens                                      0           0              0
# Number of Open Accounts                        5          16              5
# Years of Credit History                     15.7        12.4            6.3
# Maximum Open Credit                       553234      316382         162998
# Number of Credit Problems                      0           0              0
# Months since last delinquent                 NaN          73            NaN
# Bankruptcies                                   0           0              0
# Purpose                       debt consolidation       other          other
# Term                                  Short Term  Short Term     Short Term
# Current Loan Amount                       179784      442024         173800
# Current Credit Balance                    177745       88521         110238
# Monthly Debt                                3437        2313           5741
# Credit Score                                 751         738            690
#
# Id                                          9993                9994  \
# Home Ownership                              Rent       Home Mortgage
# Annual Income                        2.03828e+06              907839
# Years in current job                   10+ years              1 year
# Tax Liens                                      0                   0
# Number of Open Accounts                       15                  14
# Years of Credit History                     12.6                11.1
# Maximum Open Credit                       847000              438526
# Number of Credit Problems                      0                   0
# Months since last delinquent                 NaN                 NaN
# Bankruptcies                                   0                   0
# Purpose                       debt consolidation  debt consolidation
# Term                                  Short Term           Long Term
# Current Loan Amount                       432256              368786
# Current Credit Balance                     88521               88255
# Monthly Debt                               27177               18838
# Credit Score                                 692                 705
#
# Id                                          9995                9996  \
# Home Ownership                     Home Mortgage       Home Mortgage
# Annual Income                        1.02005e+06                 NaN
# Years in current job                   10+ years             2 years
# Tax Liens                                      0                   0
# Number of Open Accounts                       14                  15
# Years of Credit History                     29.1                  17
# Maximum Open Credit                       559152         1.73778e+06
# Number of Credit Problems                      1                   0
# Months since last delinquent                  68                  77
# Bankruptcies                                   1                   0
# Purpose                       debt consolidation  debt consolidation
# Term                                  Short Term          Short Term
# Current Loan Amount                        1e+08              468512
# Current Credit Balance                    162735         1.43927e+06
# Monthly Debt                               15046               32996
# Credit Score                                 745                 NaN
#
# Id                                          9997                9998  \
# Home Ownership                     Home Mortgage                Rent
# Annual Income                        1.17181e+06              723520
# Years in current job                     2 years           10+ years
# Tax Liens                                      0                   0
# Number of Open Accounts                       48                  14
# Years of Credit History                     12.8                28.8
# Maximum Open Credit                  1.70643e+06              945780
# Number of Credit Problems                      0                   0
# Months since last delinquent                 NaN                 NaN
# Bankruptcies                                   0                   0
# Purpose                       debt consolidation  debt consolidation
# Term                                  Short Term          Short Term
# Current Loan Amount                       430496              257774
# Current Credit Balance                    676438              391248
# Monthly Debt                               36912               13506
# Credit Score                                 695                 744
#
# Id                                          9999
# Home Ownership                              Rent
# Annual Income                        1.69444e+06
# Years in current job                   10+ years
# Tax Liens                                      0
# Number of Open Accounts                       12
# Years of Credit History                     18.4
# Maximum Open Credit                  1.19975e+06
# Number of Credit Problems                      1
# Months since last delinquent                  72
# Bankruptcies                                   0
# Purpose                       debt consolidation
# Term                                   Long Term
# Current Loan Amount                       763004
# Current Credit Balance                    559531
# Monthly Debt                               23440
# Credit Score                                6820
#
# [16 rows x 2500 columns]

# %% [markdown]
# # Performing Analysis of the dataset

# %%
# Info about the train dataset

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7500 entries, 0 to 7499
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Home Ownership                7500 non-null   object
#  1   Annual Income                 5943 non-null   float64
#  2   Years in current job          7129 non-null   object
#  3   Tax Liens                     7500 non-null   float64
#  4   Number of Open Accounts       7500 non-null   float64
#  5   Years of Credit History       7500 non-null   float64
#  6   Maximum Open Credit           7500 non-null   float64
#  7   Number of Credit Problems     7500 non-null   float64
#  8   Months since last delinquent  3419 non-null   float64
#  9   Bankruptcies                  7486 non-null   float64
#  10  Purpose                       7500 non-null   object
#  11  Term                          7500 non-null   object
#  12  Current Loan Amount           7500 non-null   float64
#  13  Current Credit Balance        7500 non-null   float64
#  14  Monthly Debt                  7500 non-null   float64
#  15  Credit Score                  5943 non-null   float64
#  16  Credit Default                7500 non-null   int64
# dtypes: float64(12), int64(1), object(4)
# memory usage: 1.3+ MB

# %%
# Stats about the train dataset

train.describe().T
# Out:
#                                count          mean           std       min  \
# Annual Income                 5943.0  1.366392e+06  8.453392e+05  164597.0
# Tax Liens                     7500.0  3.013333e-02  2.716035e-01       0.0
# Number of Open Accounts       7500.0  1.113093e+01  4.908924e+00       2.0
# Years of Credit History       7500.0  1.831747e+01  7.041946e+00       4.0
# Maximum Open Credit           7500.0  9.451537e+05  1.602622e+07       0.0
# Number of Credit Problems     7500.0  1.700000e-01  4.985978e-01       0.0
# Months since last delinquent  3419.0  3.469260e+01  2.168881e+01       0.0
# Bankruptcies                  7486.0  1.171520e-01  3.471917e-01       0.0
# Current Loan Amount           7500.0  1.187318e+07  3.192612e+07   11242.0
# Current Credit Balance        7500.0  2.898332e+05  3.178714e+05       0.0
# Monthly Debt                  7500.0  1.831445e+04  1.192676e+04       0.0
# Credit Score                  5943.0  1.151087e+03  1.604451e+03     585.0
# Credit Default                7500.0  2.817333e-01  4.498740e-01       0.0
#
#                                    25%        50%         75%           max
# Annual Income                 844341.0  1168386.0  1640137.00  1.014934e+07
# Tax Liens                          0.0        0.0        0.00  7.000000e+00
# Number of Open Accounts            8.0       10.0       14.00  4.300000e+01
# Years of Credit History           13.5       17.0       21.80  5.770000e+01
# Maximum Open Credit           279229.5   478159.0   793501.50  1.304726e+09
# Number of Credit Problems          0.0        0.0        0.00  7.000000e+00
# Months since last delinquent      16.0       32.0       50.00  1.180000e+02
# Bankruptcies                       0.0        0.0        0.00  4.000000e+00
# Current Loan Amount           180169.0   309573.0   519882.00  1.000000e+08
# Current Credit Balance        114256.5   209323.0   360406.25  6.506797e+06
# Monthly Debt                   10067.5    16076.5    23818.00  1.366790e+05
# Credit Score                     711.0      731.0      743.00  7.510000e+03
# Credit Default                     0.0        0.0        1.00  1.000000e+00

# %%
# Info about the test dataset

test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 7500 to 9999
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Home Ownership                2500 non-null   object
#  1   Annual Income                 1987 non-null   float64
#  2   Years in current job          2414 non-null   object
#  3   Tax Liens                     2500 non-null   float64
#  4   Number of Open Accounts       2500 non-null   float64
#  5   Years of Credit History       2500 non-null   float64
#  6   Maximum Open Credit           2500 non-null   float64
#  7   Number of Credit Problems     2500 non-null   float64
#  8   Months since last delinquent  1142 non-null   float64
#  9   Bankruptcies                  2497 non-null   float64
#  10  Purpose                       2500 non-null   object
#  11  Term                          2500 non-null   object
#  12  Current Loan Amount           2500 non-null   float64
#  13  Current Credit Balance        2500 non-null   float64
#  14  Monthly Debt                  2500 non-null   float64
#  15  Credit Score                  1987 non-null   float64
# dtypes: float64(12), object(4)
# memory usage: 412.0+ KB

# %%
# Stats about the test dataset

test.describe().T
# Out:
#                                count          mean           std       min  \
# Annual Income                 1987.0  1.366922e+06  9.171252e+05  106533.0
# Tax Liens                     2500.0  3.520000e-02  3.862909e-01       0.0
# Number of Open Accounts       2500.0  1.118440e+01  4.852774e+00       1.0
# Years of Credit History       2500.0  1.832592e+01  7.254659e+00       3.9
# Maximum Open Credit           2500.0  7.105704e+05  1.511983e+06       0.0
# Number of Credit Problems     2500.0  1.620000e-01  5.598941e-01       0.0
# Months since last delinquent  1142.0  3.418126e+01  2.202428e+01       0.0
# Bankruptcies                  2497.0  1.069283e-01  3.571893e-01       0.0
# Current Loan Amount           2500.0  1.215572e+07  3.226097e+07   15422.0
# Current Credit Balance        2500.0  2.963966e+05  3.783020e+05       0.0
# Monthly Debt                  2500.0  1.827134e+04  1.154388e+04      93.0
# Credit Score                  1987.0  1.234517e+03  1.740219e+03     585.0
#
#                                     25%        50%        75%         max
# Annual Income                 852311.50  1178475.0  1629734.5  14975610.0
# Tax Liens                          0.00        0.0        0.0        15.0
# Number of Open Accounts            8.00       10.0       14.0        48.0
# Years of Credit History           13.40       17.0       22.1        53.4
# Maximum Open Credit           278586.00   478676.0   802598.5  54484386.0
# Number of Credit Problems          0.00        0.0        0.0        15.0
# Months since last delinquent      16.00       30.0       50.0        82.0
# Bankruptcies                       0.00        0.0        0.0         5.0
# Current Loan Amount           187126.50   322366.0   522582.5  99999999.0
# Current Credit Balance        110114.50   207385.0   366348.5   6030087.0
# Monthly Debt                   10024.75    16642.5    24146.0     93555.0
# Credit Score                     710.00      731.0      743.0      7480.0

# %% [markdown]
# ## Changing Names of columns ::

# %%
#Deleting spaces between names and interchanging with underscore

new_cols = [str(i).lower().replace(" ", "_") for i in (list(train.columns))]
new_cols
# Out:
# ['home_ownership',
#  'annual_income',
#  'years_in_current_job',
#  'tax_liens',
#  'number_of_open_accounts',
#  'years_of_credit_history',
#  'maximum_open_credit',
#  'number_of_credit_problems',
#  'months_since_last_delinquent',
#  'bankruptcies',
#  'purpose',
#  'term',
#  'current_loan_amount',
#  'current_credit_balance',
#  'monthly_debt',
#  'credit_score',
#  'credit_default']

# %%
# Assigning new names to columns

train.columns = new_cols
test.columns = new_cols[:-1]

# %%
# Printing transpose of dataset to view all columns

train.T
# Out:
# Id                                          0                   1     \
# home_ownership                          Own Home            Own Home
# annual_income                             482087         1.02549e+06
# years_in_current_job                         NaN           10+ years
# tax_liens                                      0                   0
# number_of_open_accounts                       11                  15
# years_of_credit_history                     26.3                15.3
# maximum_open_credit                       685960         1.18173e+06
# number_of_credit_problems                      1                   0
# months_since_last_delinquent                 NaN                 NaN
# bankruptcies                                   1                   0
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term           Long Term
# current_loan_amount                        1e+08              264968
# current_credit_balance                     47386              394972
# monthly_debt                                7914               18373
# credit_score                                 749                 737
# credit_default                                 0                   1
#
# Id                                          2                   3     \
# home_ownership                     Home Mortgage            Own Home
# annual_income                             751412              805068
# years_in_current_job                     8 years             6 years
# tax_liens                                      0                   0
# number_of_open_accounts                       11                   8
# years_of_credit_history                       35                22.5
# maximum_open_credit                  1.18243e+06              147400
# number_of_credit_problems                      0                   1
# months_since_last_delinquent                 NaN                 NaN
# bankruptcies                                   0                   1
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term          Short Term
# current_loan_amount                        1e+08              121396
# current_credit_balance                    308389               95855
# monthly_debt                               13651               11338
# credit_score                                 742                 694
# credit_default                                 0                   0
#
# Id                                          4          5     \
# home_ownership                              Rent       Rent
# annual_income                             776264        NaN
# years_in_current_job                     8 years    7 years
# tax_liens                                      0          0
# number_of_open_accounts                       13         12
# years_of_credit_history                     13.6       14.6
# maximum_open_credit                       385836     366784
# number_of_credit_problems                      1          0
# months_since_last_delinquent                 NaN        NaN
# bankruptcies                                   0          0
# purpose                       debt consolidation      other
# term                                  Short Term  Long Term
# current_loan_amount                       125840     337304
# current_credit_balance                     93309     165680
# monthly_debt                                7180      18692
# credit_score                                 719        NaN
# credit_default                                 0          1
#
# Id                                         6            7     \
# home_ownership                    Home Mortgage         Rent
# annual_income                       1.51111e+06  1.04006e+06
# years_in_current_job                  10+ years    10+ years
# tax_liens                                     0            0
# number_of_open_accounts                       9           13
# years_of_credit_history                    20.3           12
# maximum_open_credit                      388124       330374
# number_of_credit_problems                     0            0
# months_since_last_delinquent                 73           18
# bankruptcies                                  0            0
# purpose                       home improvements        other
# term                                 Short Term   Short Term
# current_loan_amount                       1e+08       250888
# current_credit_balance                    51623        89015
# monthly_debt                               2317        19761
# credit_score                                745          705
# credit_default                                0            1
#
# Id                                         8                   9     ...  \
# home_ownership                    Home Mortgage       Home Mortgage  ...
# annual_income                               NaN                 NaN  ...
# years_in_current_job                    5 years              1 year  ...
# tax_liens                                     0                   0  ...
# number_of_open_accounts                      17                  10  ...
# years_of_credit_history                    15.7                24.6  ...
# maximum_open_credit                           0              511302  ...
# number_of_credit_problems                     1                   0  ...
# months_since_last_delinquent                NaN                   6  ...
# bankruptcies                                  1                   0  ...
# purpose                       home improvements  debt consolidation  ...
# term                                 Short Term           Long Term  ...
# current_loan_amount                      129734              572880  ...
# current_credit_balance                       19              205333  ...
# monthly_debt                                 17               17613  ...
# credit_score                                NaN                 NaN  ...
# credit_default                                0                   1  ...
#
# Id                                          7490                7491  \
# home_ownership                          Own Home       Home Mortgage
# annual_income                          1.368e+06         2.83318e+06
# years_in_current_job                   10+ years             6 years
# tax_liens                                      0                   0
# number_of_open_accounts                       20                  18
# years_of_credit_history                     26.7                21.3
# maximum_open_credit                       897842              280170
# number_of_credit_problems                      0                   0
# months_since_last_delinquent                  69                   6
# bankruptcies                                   0                   0
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term          Short Term
# current_loan_amount                       683650              437404
# current_credit_balance                    517199              108889
# monthly_debt                               29868               61150
# credit_score                                 688                 704
# credit_default                                 1                   0
#
# Id                                          7492                7493  \
# home_ownership                     Home Mortgage                Rent
# annual_income                                NaN         1.25761e+06
# years_in_current_job                   10+ years             8 years
# tax_liens                                      0                   0
# number_of_open_accounts                       10                  14
# years_of_credit_history                     13.3                16.5
# maximum_open_credit                       423984              821480
# number_of_credit_problems                      0                   0
# months_since_last_delinquent                 NaN                  58
# bankruptcies                                   0                   0
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term           Long Term
# current_loan_amount                       332948              448052
# current_credit_balance                    161481              167428
# monthly_debt                               20966               27562
# credit_score                                 NaN                 676
# credit_default                                 0                   1
#
# Id                                          7494        7495  \
# home_ownership                          Own Home        Rent
# annual_income                                NaN      402192
# years_in_current_job                    < 1 year    < 1 year
# tax_liens                                      0           0
# number_of_open_accounts                        7           3
# years_of_credit_history                      8.2         8.5
# maximum_open_credit                       301554      107866
# number_of_credit_problems                      0           0
# months_since_last_delinquent                 NaN         NaN
# bankruptcies                                   0           0
# purpose                       debt consolidation       other
# term                                  Short Term  Short Term
# current_loan_amount                       290400      129360
# current_credit_balance                    210938       73492
# monthly_debt                                5070        1900
# credit_score                                 NaN         697
# credit_default                                 0           0
#
# Id                                          7496         7497  \
# home_ownership                     Home Mortgage         Rent
# annual_income                        1.53398e+06  1.87891e+06
# years_in_current_job                      1 year      6 years
# tax_liens                                      0            0
# number_of_open_accounts                       10           12
# years_of_credit_history                     26.5         32.1
# maximum_open_credit                       686312  1.77892e+06
# number_of_credit_problems                      0            0
# months_since_last_delinquent                  43          NaN
# bankruptcies                                   0            0
# purpose                       debt consolidation    buy a car
# term                                   Long Term   Short Term
# current_loan_amount                       444048        1e+08
# current_credit_balance                    456399       477812
# monthly_debt                               12783        12479
# credit_score                                7410          748
# credit_default                                 1            0
#
# Id                                          7498                7499
# home_ownership                     Home Mortgage                Rent
# annual_income                                NaN                 NaN
# years_in_current_job                         NaN             4 years
# tax_liens                                      0                   0
# number_of_open_accounts                       21                   8
# years_of_credit_history                     26.5                 9.4
# maximum_open_credit                  1.14125e+06              480832
# number_of_credit_problems                      0                   0
# months_since_last_delinquent                 NaN                 NaN
# bankruptcies                                   0                   0
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term          Short Term
# current_loan_amount                       615274               26928
# current_credit_balance                    476064              288192
# monthly_debt                               37118                9061
# credit_score                                 NaN                 NaN
# credit_default                                 0                   0
#
# [17 rows x 7500 columns]

# %%
# Printing transpose of dataset to view all columns

test.T
# Out:
# Id                                          7500                  7501  \
# home_ownership                              Rent                  Rent
# annual_income                                NaN                231838
# years_in_current_job                     4 years                1 year
# tax_liens                                      0                     0
# number_of_open_accounts                        9                     6
# years_of_credit_history                     12.5                  32.7
# maximum_open_credit                       220968                 55946
# number_of_credit_problems                      0                     0
# months_since_last_delinquent                  70                     8
# bankruptcies                                   0                     0
# purpose                       debt consolidation  educational expenses
# term                                  Short Term            Short Term
# current_loan_amount                       162470                 78298
# current_credit_balance                    105906                 46037
# monthly_debt                                6813                  2318
# credit_score                                 NaN                   699
#
# Id                                          7502                7503  \
# home_ownership                     Home Mortgage       Home Mortgage
# annual_income                        1.15254e+06         1.22031e+06
# years_in_current_job                     3 years           10+ years
# tax_liens                                      0                   0
# number_of_open_accounts                       10                  16
# years_of_credit_history                     13.7                  17
# maximum_open_credit                       204600              456302
# number_of_credit_problems                      0                   0
# months_since_last_delinquent                 NaN                  70
# bankruptcies                                   0                   0
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term          Short Term
# current_loan_amount                       200178              217382
# current_credit_balance                    146490              213199
# monthly_debt                               18729               27559
# credit_score                                7260                 739
#
# Id                                          7504                7505  \
# home_ownership                     Home Mortgage       Home Mortgage
# annual_income                        2.34095e+06              922583
# years_in_current_job                     6 years             5 years
# tax_liens                                      0                   0
# number_of_open_accounts                       11                  26
# years_of_credit_history                     23.6                17.5
# maximum_open_credit                  1.20727e+06              713174
# number_of_credit_problems                      0                   0
# months_since_last_delinquent                 NaN                  41
# bankruptcies                                   0                   0
# purpose                       debt consolidation  debt consolidation
# term                                   Long Term          Short Term
# current_loan_amount                       777634               94028
# current_credit_balance                    425391              135508
# monthly_debt                               42605               11148
# credit_score                                 706                 679
#
# Id                                         7506                7507  \
# home_ownership                    Home Mortgage                Rent
# annual_income                       1.23331e+06         1.21587e+06
# years_in_current_job                    3 years             3 years
# tax_liens                                     0                   0
# number_of_open_accounts                       7                  13
# years_of_credit_history                      22                12.2
# maximum_open_credit                      376420              195888
# number_of_credit_problems                     0                   0
# months_since_last_delinquent                 43                  19
# bankruptcies                                  0                   0
# purpose                       home improvements  debt consolidation
# term                                 Short Term          Short Term
# current_loan_amount                      454388              407726
# current_credit_balance                   292904              120099
# monthly_debt                               8181                7599
# credit_score                                685                 701
#
# Id                                      7508                7509  ...  \
# home_ownership                          Rent       Home Mortgage  ...
# annual_income                            NaN         2.14044e+06  ...
# years_in_current_job                 5 years           10+ years  ...
# tax_liens                                  0                   1  ...
# number_of_open_accounts                    8                  15  ...
# years_of_credit_history                  9.1                16.7  ...
# maximum_open_credit                   370524              867680  ...
# number_of_credit_problems                  0                   1  ...
# months_since_last_delinquent             NaN                   9  ...
# bankruptcies                               0                   0  ...
# purpose                       major purchase  debt consolidation  ...
# term                              Short Term          Short Term  ...
# current_loan_amount                   131956              391336  ...
# current_credit_balance                237747              294500  ...
# monthly_debt                           10112               18372  ...
# credit_score                             NaN                 745  ...
#
# Id                                          9990        9991           9992  \
# home_ownership                     Home Mortgage        Rent  Home Mortgage
# annual_income                        1.49446e+06      916199         750500
# years_in_current_job                   10+ years     2 years        3 years
# tax_liens                                      0           0              0
# number_of_open_accounts                        5          16              5
# years_of_credit_history                     15.7        12.4            6.3
# maximum_open_credit                       553234      316382         162998
# number_of_credit_problems                      0           0              0
# months_since_last_delinquent                 NaN          73            NaN
# bankruptcies                                   0           0              0
# purpose                       debt consolidation       other          other
# term                                  Short Term  Short Term     Short Term
# current_loan_amount                       179784      442024         173800
# current_credit_balance                    177745       88521         110238
# monthly_debt                                3437        2313           5741
# credit_score                                 751         738            690
#
# Id                                          9993                9994  \
# home_ownership                              Rent       Home Mortgage
# annual_income                        2.03828e+06              907839
# years_in_current_job                   10+ years              1 year
# tax_liens                                      0                   0
# number_of_open_accounts                       15                  14
# years_of_credit_history                     12.6                11.1
# maximum_open_credit                       847000              438526
# number_of_credit_problems                      0                   0
# months_since_last_delinquent                 NaN                 NaN
# bankruptcies                                   0                   0
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term           Long Term
# current_loan_amount                       432256              368786
# current_credit_balance                     88521               88255
# monthly_debt                               27177               18838
# credit_score                                 692                 705
#
# Id                                          9995                9996  \
# home_ownership                     Home Mortgage       Home Mortgage
# annual_income                        1.02005e+06                 NaN
# years_in_current_job                   10+ years             2 years
# tax_liens                                      0                   0
# number_of_open_accounts                       14                  15
# years_of_credit_history                     29.1                  17
# maximum_open_credit                       559152         1.73778e+06
# number_of_credit_problems                      1                   0
# months_since_last_delinquent                  68                  77
# bankruptcies                                   1                   0
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term          Short Term
# current_loan_amount                        1e+08              468512
# current_credit_balance                    162735         1.43927e+06
# monthly_debt                               15046               32996
# credit_score                                 745                 NaN
#
# Id                                          9997                9998  \
# home_ownership                     Home Mortgage                Rent
# annual_income                        1.17181e+06              723520
# years_in_current_job                     2 years           10+ years
# tax_liens                                      0                   0
# number_of_open_accounts                       48                  14
# years_of_credit_history                     12.8                28.8
# maximum_open_credit                  1.70643e+06              945780
# number_of_credit_problems                      0                   0
# months_since_last_delinquent                 NaN                 NaN
# bankruptcies                                   0                   0
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term          Short Term
# current_loan_amount                       430496              257774
# current_credit_balance                    676438              391248
# monthly_debt                               36912               13506
# credit_score                                 695                 744
#
# Id                                          9999
# home_ownership                              Rent
# annual_income                        1.69444e+06
# years_in_current_job                   10+ years
# tax_liens                                      0
# number_of_open_accounts                       12
# years_of_credit_history                     18.4
# maximum_open_credit                  1.19975e+06
# number_of_credit_problems                      1
# months_since_last_delinquent                  72
# bankruptcies                                   0
# purpose                       debt consolidation
# term                                   Long Term
# current_loan_amount                       763004
# current_credit_balance                    559531
# monthly_debt                               23440
# credit_score                                6820
#
# [16 rows x 2500 columns]

# %%
## Since renewable energy has no value hence analyzing it

print(train.purpose.value_counts(dropna = False)), print('*' * 80, '\n'), print(test.purpose.value_counts(dropna = False))
# Out:
# debt consolidation      5944
# other                    665
# home improvements        412
# business loan            129
# buy a car                 96
# medical bills             71
# major purchase            40
# take a trip               37
# buy house                 34
# small business            26
# wedding                   15
# moving                    11
# educational expenses      10
# vacation                   8
# renewable energy           2
# Name: purpose, dtype: int64
# ********************************************************************************
#
# debt consolidation      1973
# other                    240
# home improvements        140
# buy a car                 34
# business loan             30
# medical bills             27
# buy house                 19
# take a trip               14
# major purchase             9
# small business             5
# educational expenses       3
# vacation                   3
# wedding                    2
# moving                     1
# Name: purpose, dtype: int64
# (None, None, None)

# %% [markdown]
# ### Since Renewable energy category is missing in test data so after converting it in dummy variable it will create a mismatch in modelling. Since number of columns in dummy variable will be one less . Hence dropping it now.

# %%
train = train[train.purpose != 'renewable energy']
train.T
# Out:
# Id                                          0                   1     \
# home_ownership                          Own Home            Own Home
# annual_income                             482087         1.02549e+06
# years_in_current_job                         NaN           10+ years
# tax_liens                                      0                   0
# number_of_open_accounts                       11                  15
# years_of_credit_history                     26.3                15.3
# maximum_open_credit                       685960         1.18173e+06
# number_of_credit_problems                      1                   0
# months_since_last_delinquent                 NaN                 NaN
# bankruptcies                                   1                   0
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term           Long Term
# current_loan_amount                        1e+08              264968
# current_credit_balance                     47386              394972
# monthly_debt                                7914               18373
# credit_score                                 749                 737
# credit_default                                 0                   1
#
# Id                                          2                   3     \
# home_ownership                     Home Mortgage            Own Home
# annual_income                             751412              805068
# years_in_current_job                     8 years             6 years
# tax_liens                                      0                   0
# number_of_open_accounts                       11                   8
# years_of_credit_history                       35                22.5
# maximum_open_credit                  1.18243e+06              147400
# number_of_credit_problems                      0                   1
# months_since_last_delinquent                 NaN                 NaN
# bankruptcies                                   0                   1
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term          Short Term
# current_loan_amount                        1e+08              121396
# current_credit_balance                    308389               95855
# monthly_debt                               13651               11338
# credit_score                                 742                 694
# credit_default                                 0                   0
#
# Id                                          4          5     \
# home_ownership                              Rent       Rent
# annual_income                             776264        NaN
# years_in_current_job                     8 years    7 years
# tax_liens                                      0          0
# number_of_open_accounts                       13         12
# years_of_credit_history                     13.6       14.6
# maximum_open_credit                       385836     366784
# number_of_credit_problems                      1          0
# months_since_last_delinquent                 NaN        NaN
# bankruptcies                                   0          0
# purpose                       debt consolidation      other
# term                                  Short Term  Long Term
# current_loan_amount                       125840     337304
# current_credit_balance                     93309     165680
# monthly_debt                                7180      18692
# credit_score                                 719        NaN
# credit_default                                 0          1
#
# Id                                         6            7     \
# home_ownership                    Home Mortgage         Rent
# annual_income                       1.51111e+06  1.04006e+06
# years_in_current_job                  10+ years    10+ years
# tax_liens                                     0            0
# number_of_open_accounts                       9           13
# years_of_credit_history                    20.3           12
# maximum_open_credit                      388124       330374
# number_of_credit_problems                     0            0
# months_since_last_delinquent                 73           18
# bankruptcies                                  0            0
# purpose                       home improvements        other
# term                                 Short Term   Short Term
# current_loan_amount                       1e+08       250888
# current_credit_balance                    51623        89015
# monthly_debt                               2317        19761
# credit_score                                745          705
# credit_default                                0            1
#
# Id                                         8                   9     ...  \
# home_ownership                    Home Mortgage       Home Mortgage  ...
# annual_income                               NaN                 NaN  ...
# years_in_current_job                    5 years              1 year  ...
# tax_liens                                     0                   0  ...
# number_of_open_accounts                      17                  10  ...
# years_of_credit_history                    15.7                24.6  ...
# maximum_open_credit                           0              511302  ...
# number_of_credit_problems                     1                   0  ...
# months_since_last_delinquent                NaN                   6  ...
# bankruptcies                                  1                   0  ...
# purpose                       home improvements  debt consolidation  ...
# term                                 Short Term           Long Term  ...
# current_loan_amount                      129734              572880  ...
# current_credit_balance                       19              205333  ...
# monthly_debt                                 17               17613  ...
# credit_score                                NaN                 NaN  ...
# credit_default                                0                   1  ...
#
# Id                                          7490                7491  \
# home_ownership                          Own Home       Home Mortgage
# annual_income                          1.368e+06         2.83318e+06
# years_in_current_job                   10+ years             6 years
# tax_liens                                      0                   0
# number_of_open_accounts                       20                  18
# years_of_credit_history                     26.7                21.3
# maximum_open_credit                       897842              280170
# number_of_credit_problems                      0                   0
# months_since_last_delinquent                  69                   6
# bankruptcies                                   0                   0
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term          Short Term
# current_loan_amount                       683650              437404
# current_credit_balance                    517199              108889
# monthly_debt                               29868               61150
# credit_score                                 688                 704
# credit_default                                 1                   0
#
# Id                                          7492                7493  \
# home_ownership                     Home Mortgage                Rent
# annual_income                                NaN         1.25761e+06
# years_in_current_job                   10+ years             8 years
# tax_liens                                      0                   0
# number_of_open_accounts                       10                  14
# years_of_credit_history                     13.3                16.5
# maximum_open_credit                       423984              821480
# number_of_credit_problems                      0                   0
# months_since_last_delinquent                 NaN                  58
# bankruptcies                                   0                   0
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term           Long Term
# current_loan_amount                       332948              448052
# current_credit_balance                    161481              167428
# monthly_debt                               20966               27562
# credit_score                                 NaN                 676
# credit_default                                 0                   1
#
# Id                                          7494        7495  \
# home_ownership                          Own Home        Rent
# annual_income                                NaN      402192
# years_in_current_job                    < 1 year    < 1 year
# tax_liens                                      0           0
# number_of_open_accounts                        7           3
# years_of_credit_history                      8.2         8.5
# maximum_open_credit                       301554      107866
# number_of_credit_problems                      0           0
# months_since_last_delinquent                 NaN         NaN
# bankruptcies                                   0           0
# purpose                       debt consolidation       other
# term                                  Short Term  Short Term
# current_loan_amount                       290400      129360
# current_credit_balance                    210938       73492
# monthly_debt                                5070        1900
# credit_score                                 NaN         697
# credit_default                                 0           0
#
# Id                                          7496         7497  \
# home_ownership                     Home Mortgage         Rent
# annual_income                        1.53398e+06  1.87891e+06
# years_in_current_job                      1 year      6 years
# tax_liens                                      0            0
# number_of_open_accounts                       10           12
# years_of_credit_history                     26.5         32.1
# maximum_open_credit                       686312  1.77892e+06
# number_of_credit_problems                      0            0
# months_since_last_delinquent                  43          NaN
# bankruptcies                                   0            0
# purpose                       debt consolidation    buy a car
# term                                   Long Term   Short Term
# current_loan_amount                       444048        1e+08
# current_credit_balance                    456399       477812
# monthly_debt                               12783        12479
# credit_score                                7410          748
# credit_default                                 1            0
#
# Id                                          7498                7499
# home_ownership                     Home Mortgage                Rent
# annual_income                                NaN                 NaN
# years_in_current_job                         NaN             4 years
# tax_liens                                      0                   0
# number_of_open_accounts                       21                   8
# years_of_credit_history                     26.5                 9.4
# maximum_open_credit                  1.14125e+06              480832
# number_of_credit_problems                      0                   0
# months_since_last_delinquent                 NaN                 NaN
# bankruptcies                                   0                   0
# purpose                       debt consolidation  debt consolidation
# term                                  Short Term          Short Term
# current_loan_amount                       615274               26928
# current_credit_balance                    476064              288192
# monthly_debt                               37118                9061
# credit_score                                 NaN                 NaN
# credit_default                                 0                   0
#
# [17 rows x 7498 columns]

# %% [markdown]
# ## Dataframe with dataset info

# %%
# Creating a dataframe that contains various values to corresponding columns

mask = train.isnull()                  # calculate total null values
total = mask.sum()                    # calculate the sum
percent = 100 * mask.mean()           # calculate the percent missing values
dtype = train.dtypes                   # getting the data types of the columns
unique = train.nunique()               # getting the all unique values of the columns


# creating a dataframe

null_train = pd.concat([total, percent, dtype, unique], 
                       axis = 1, 
                       keys = ['Total Count', 'Percent Missing', 'dtype', 'Unique Values'])

null_train.sort_values(by = 'Total Count', ascending = False)
# Out:
#                               Total Count  Percent Missing    dtype  \
# months_since_last_delinquent         4080        54.414511  float64
# credit_score                         1555        20.738864  float64
# annual_income                        1555        20.738864  float64
# years_in_current_job                  371         4.947986   object
# bankruptcies                           14         0.186716  float64
# purpose                                 0         0.000000   object
# monthly_debt                            0         0.000000  float64
# current_credit_balance                  0         0.000000  float64
# current_loan_amount                     0         0.000000  float64
# term                                    0         0.000000   object
# home_ownership                          0         0.000000   object
# number_of_credit_problems               0         0.000000  float64
# maximum_open_credit                     0         0.000000  float64
# years_of_credit_history                 0         0.000000  float64
# number_of_open_accounts                 0         0.000000  float64
# tax_liens                               0         0.000000  float64
# credit_default                          0         0.000000    int64
#
#                               Unique Values
# months_since_last_delinquent             89
# credit_score                            268
# annual_income                          5478
# years_in_current_job                     11
# bankruptcies                              5
# purpose                                  14
# monthly_debt                           6715
# current_credit_balance                 6591
# current_loan_amount                    5384
# term                                      2
# home_ownership                            4
# number_of_credit_problems                 8
# maximum_open_credit                    6961
# years_of_credit_history                 408
# number_of_open_accounts                  39
# tax_liens                                 8
# credit_default                            2

# %%
mask1 = test.isnull()                          # calculate total null values
total1 = mask1.sum()                           # calculate the sum
percent1 = 100 * mask1.mean()                  # calculate the percent missing values
dtype1 = test.dtypes                           # getting the data types of the columns
unique1 = test.nunique()                       # getting the all unique values of the columns

null_test = pd.concat([total1, percent1, dtype1, unique1], 
                      axis = 1, 
                      keys = ['Total Count', 'Percent Missing', 'dtype', 'Unique Values'])


# Soritng the values by count

null_test.sort_values(by = 'Total Count', ascending = False)
# Out:
#                               Total Count  Percent Missing    dtype  \
# months_since_last_delinquent         1358            54.32  float64
# annual_income                         513            20.52  float64
# credit_score                          513            20.52  float64
# years_in_current_job                   86             3.44   object
# bankruptcies                            3             0.12  float64
# home_ownership                          0             0.00   object
# tax_liens                               0             0.00  float64
# number_of_open_accounts                 0             0.00  float64
# years_of_credit_history                 0             0.00  float64
# maximum_open_credit                     0             0.00  float64
# number_of_credit_problems               0             0.00  float64
# purpose                                 0             0.00   object
# term                                    0             0.00   object
# current_loan_amount                     0             0.00  float64
# current_credit_balance                  0             0.00  float64
# monthly_debt                            0             0.00  float64
#
#                               Unique Values
# months_since_last_delinquent             83
# annual_income                          1929
# credit_score                            211
# years_in_current_job                     11
# bankruptcies                              6
# home_ownership                            4
# tax_liens                                 8
# number_of_open_accounts                  35
# years_of_credit_history                 345
# maximum_open_credit                    2435
# number_of_credit_problems                 8
# purpose                                  14
# term                                      2
# current_loan_amount                    2026
# current_credit_balance                 2385
# monthly_debt                           2416

# %% [markdown]
# # Data Visualization ::

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize = (20,10))
sns.heatmap(train.corr(), annot = True, vmax = 1, vmin = -1, square = True)

# %% [markdown]
# ## Selecting columns with missing values and observing their relationships with other features

# %%
plt.figure(figsize = (17,7))
sns.barplot(y = train.months_since_last_delinquent, x = train.bankruptcies, data = train)

# %%
plt.figure(figsize = (17,7))
sns.barplot(y = train.months_since_last_delinquent, x = train.number_of_credit_problems, data = train)

# %%
plt.figure(figsize = (17,7))
sns.barplot(y = train.months_since_last_delinquent, x = train.purpose, data = train)

# %% [markdown]
# ## Observation ::
#
# - Months increase with increase in bankrupcies
# - So both are highly dependent to each other
# - We can try to fill the missing months with respective bankrupcies
# - Since bankruptcies also has missing values hence filling it with mode value

# %% [markdown]
# ## Printing all unique values present in corresponding columns

# %%
print('Tax Liens Value Counts ::\n\n', train.tax_liens.value_counts(dropna = False))
print('*' * 80)
print('\nbankruptcies Value Counts ::\n\n', train.bankruptcies.value_counts(dropna = False))
# Out:
# Tax Liens Value Counts ::
#
#  0.0    7364
# 1.0      83
# 2.0      30
# 3.0      10
# 4.0       6
# 5.0       2
# 6.0       2
# 7.0       1
# Name: tax_liens, dtype: int64
# ********************************************************************************
#
# bankruptcies Value Counts ::
#
#  0.0    6658
# 1.0     786
# 2.0      31
# NaN      14
# 3.0       7
# 4.0       2
# Name: bankruptcies, dtype: int64

# %%
print('purpose Value Counts ::\n\n', train.purpose.value_counts(dropna = False))
print('*' * 80)
print('\number_of_credit_problems Value Counts ::\n\n', train.number_of_credit_problems.value_counts(dropna = False))
# Out:
# purpose Value Counts ::
#
#  debt consolidation      5944
# other                    665
# home improvements        412
# business loan            129
# buy a car                 96
# medical bills             71
# major purchase            40
# take a trip               37
# buy house                 34
# small business            26
# wedding                   15
# moving                    11
# educational expenses      10
# vacation                   8
# Name: purpose, dtype: int64
# ********************************************************************************
#
# umber_of_credit_problems Value Counts ::
#
#  0.0    6467
# 1.0     882
# 2.0      93
# 3.0      35
# 4.0       9
# 5.0       7
# 6.0       4
# 7.0       1
# Name: number_of_credit_problems, dtype: int64

# %% [markdown]
# ## Observation ::
#
# - number_of_credit_problems, tax_liens, bankruptcies have abnormally distributed values hence we can't use these column in filling missing values
# - purpose has nearly normally distributed values hence it can be used

# %% [markdown]
# ---
# # Missing Values Imputation ::

# %% [markdown]
# ## Filling missing values of 'bankruptcies' column

# %%
train.bankruptcies.value_counts(dropna = False)
# Out:
# 0.0    6658
# 1.0     786
# 2.0      31
# NaN      14
# 3.0       7
# 4.0       2
# Name: bankruptcies, dtype: int64

# %%
from scipy.stats import mode

# Filling with mode value

train.bankruptcies =  train.bankruptcies.agg(lambda x : x.fillna(value = 2.0))

# Checking for NaN values present

print('Total NaN values present after filling :: ', train.bankruptcies.isna().sum())
# Out:
# Total NaN values present after filling ::  0

# %%
train.bankruptcies.value_counts(dropna = False)
# Out:
# 0.0    6658
# 1.0     786
# 2.0      45
# 3.0       7
# 4.0       2
# Name: bankruptcies, dtype: int64

# %% [markdown]
# ## Filling missing values of 'months_since_last_delinquent' column

# %%
# Checking values before the filled values 

train['months_since_last_delinquent'].value_counts(dropna = False)
# Out:
# NaN      4080
# 14.0       76
# 29.0       71
# 8.0        68
# 33.0       68
#          ...
# 84.0        1
# 92.0        1
# 86.0        1
# 118.0       1
# 91.0        1
# Name: months_since_last_delinquent, Length: 90, dtype: int64

# %%
# Grouping months_since_last_delinquent columns as per  'purpose', 'home_ownership'

mean_score = train.groupby(['tax_liens','bankruptcies','number_of_credit_problems'])['months_since_last_delinquent']
mean_score.agg([np.mean, np.median, np.size])
# Out:
#                                                        mean  median    size
# tax_liens bankruptcies number_of_credit_problems
# 0.0       0.0          0.0                        33.419745    31.0  6453.0
#                        1.0                        36.393443    32.0    88.0
#                        2.0                        48.250000    44.5    11.0
#                        3.0                        27.333333    29.0     3.0
#                        4.0                        39.000000    39.0     2.0
#                        5.0                        33.000000    31.0     3.0
#           1.0          1.0                        43.751572    46.0   738.0
#                        2.0                        45.500000    42.0    12.0
#                        3.0                        80.000000    80.0     2.0
#           2.0          0.0                        12.071429     0.0    14.0
#                        2.0                        49.916667    55.5    26.0
#                        3.0                        37.500000    37.5     3.0
#           3.0          3.0                        65.250000    67.0     7.0
#           4.0          4.0                        78.000000    78.0     2.0
# 1.0       0.0          1.0                        35.714286    32.0    56.0
#                        2.0                        25.200000    17.0     7.0
#           1.0          2.0                        44.666667    48.0    19.0
#           2.0          4.0                        46.000000    46.0     1.0
# 2.0       0.0          2.0                        41.615385    34.0    18.0
#                        3.0                              NaN     NaN     1.0
#           1.0          3.0                        47.600000    62.0    10.0
#                        4.0                              NaN     NaN     1.0
# 3.0       0.0          3.0                        42.400000    37.0     9.0
#           1.0          4.0                        26.000000    26.0     1.0
# 4.0       0.0          4.0                        43.000000    43.0     2.0
#                        5.0                        36.000000    36.0     1.0
#           1.0          5.0                        49.500000    49.5     2.0
#           2.0          6.0                        71.000000    71.0     1.0
# 5.0       0.0          5.0                        71.000000    71.0     1.0
#           1.0          6.0                        56.000000    56.0     1.0
# 6.0       0.0          6.0                        46.500000    46.5     2.0
# 7.0       0.0          7.0                        54.000000    54.0     1.0

# %%
train.loc[: , 'months_since_last_delinquent'] = mean_score.transform(lambda x : x.fillna(x.median()))

#Using ffill to fill any left missing value

train.months_since_last_delinquent = train.months_since_last_delinquent.fillna(method = 'ffill')
# Checking for NaN values present

print('Total NaN values present after filling :: ', train.months_since_last_delinquent.isna().sum())
# Out:
# Total NaN values present after filling ::  0

# %%
train['months_since_last_delinquent'].value_counts(dropna = False)
# Out:
# 31.0     3608
# 46.0      466
# 32.0       99
# 14.0       76
# 29.0       71
#          ...
# 84.0        1
# 86.0        1
# 91.0        1
# 118.0       1
# 37.5        1
# Name: months_since_last_delinquent, Length: 92, dtype: int64

# %% [raw]
# # filling missing values using forward fill and backward fill method
#
# train.months_since_last_delinquent = train.months_since_last_delinquent.fillna(method = 'ffill', limit = 3)
# train.months_since_last_delinquent = train.months_since_last_delinquent.fillna(method = 'bfill', limit = 3)
#
# train['months_since_last_delinquent'].isna().sum()
# #train['months_since_last_delinquent'].value_counts(dropna = False).sort_values(ascending = False).head(30)

# %% [markdown]
# ## Filling 'years_in_current_job'  column ::

# %%
print('Total NaN values present before filling :: ', train.years_in_current_job.isna().sum())

# Displaying total unique values present 

train.years_in_current_job.value_counts(dropna = False)
# Out:
# Total NaN values present before filling ::  371
# 10+ years    2331
# 2 years       705
# 3 years       619
# < 1 year      563
# 5 years       516
# 1 year        504
# 4 years       469
# 6 years       426
# 7 years       396
# NaN           371
# 8 years       339
# 9 years       259
# Name: years_in_current_job, dtype: int64

# %%
### Since NaN values present hence filling it using ffill and bfill 

train.years_in_current_job.fillna(method = 'ffill', inplace = True)
train.years_in_current_job.fillna(method = 'bfill', inplace = True)


# Checking for NaN values present
print('Total NaN values present after filling :: ', train.years_in_current_job.isna().sum())

train.years_in_current_job.value_counts(dropna = False)
# Out:
# Total NaN values present after filling ::  0
# 10+ years    2464
# 2 years       736
# 3 years       651
# < 1 year      591
# 5 years       540
# 1 year        531
# 4 years       489
# 6 years       452
# 7 years       418
# 8 years       361
# 9 years       265
# Name: years_in_current_job, dtype: int64

# %% [markdown]
# ## Filling missing values of Annual Income column
#
# - Annual Income and Monthly debt are highly correlated :: 0.58
# - Annual Income and Current credti balance also related :: 0.38
# - So considering both columns to fill missing values of annual income column

# %% [markdown]
# ## Visualizing all three column : annual_income, current_credit_balance, monthly_debt

# %%
# Visualizing to see its relationship with other columns

plt.figure(figsize = (20,8))
sns.barplot(x = train.number_of_credit_problems, y = train.annual_income, data = train)

# %%
plt.figure(figsize = (20,8))
sns.barplot(x = train.purpose, y = train.annual_income, data = train)

# %%
# Again visualizing 

plt.figure(figsize = (20,8))
sns.barplot(x = train.years_in_current_job, y = train.annual_income, data = train)

# %%
plt.figure(figsize = (20,8))
sns.barplot(x = train.number_of_open_accounts, y = train.annual_income, data = train)

# %% [markdown]
# ## Filling 'annual_income' column ::

# %%
# Displaying total unique values

train.annual_income.value_counts(dropna = False)
# Out:
# NaN          1555
# 1161660.0       4
# 1058376.0       4
# 1043651.0       4
# 1338113.0       4
#              ...
# 1141254.0       1
# 7907382.0       1
# 1534478.0       1
# 972040.0        1
# 585751.0        1
# Name: annual_income, Length: 5479, dtype: int64

# %%
val = train.groupby(['purpose','years_in_current_job'])['annual_income']
val.agg([np.mean, np.median, np.size])
# Out:
#                                             mean     median  size
# purpose       years_in_current_job
# business loan 1 year                1.400614e+06  1076473.5   9.0
#               10+ years             2.168459e+06  1664770.5  24.0
#               2 years               1.811316e+06  1428287.0  10.0
#               3 years               1.243116e+06  1153623.0  16.0
#               4 years               1.125440e+06  1172984.0   9.0
# ...                                          ...        ...   ...
# wedding       3 years               6.620208e+06  6620208.0   1.0
#               4 years               1.061454e+06  1061454.0   1.0
#               5 years               1.002256e+06  1023169.0   4.0
#               6 years               9.411080e+05   941108.0   1.0
#               9 years               3.335431e+06  3335431.0   1.0
#
# [129 rows x 3 columns]

# %%
#tranforming/applying mean values to corresponding rows with missing values

train.annual_income = val.transform(lambda x : x.fillna(x.median()))
train.annual_income = train.annual_income.fillna(method = 'ffill')
# Checking for NaN values present

print('Total NaN values present after filling :: ', train.annual_income.isna().sum())

#Displaying values

train.annual_income.value_counts(dropna = False)
# Out:
# Total NaN values present after filling ::  0
# 1305927.0    402
# 1072398.0    116
# 1149405.0    103
# 1019749.0     92
# 1090932.5     92
#             ...
# 1045741.0      1
# 1567196.0      1
# 7883442.0      1
# 767220.0       1
# 1654786.0      1
# Name: annual_income, Length: 5514, dtype: int64

# %%
plt.figure(figsize = (20,8))
sns.boxplot(train.annual_income, data = train)

# %% [markdown]
# ## Filling 'credit_score' column ::

# %%
# Displaying total unique values

train.credit_score.value_counts(dropna = False)
# Out:
# NaN       1555
# 740.0      169
# 747.0      168
# 748.0      157
# 745.0      152
#           ...
# 602.0        1
# 616.0        1
# 585.0        1
# 620.0        1
# 7010.0       1
# Name: credit_score, Length: 269, dtype: int64

# %% [markdown]
# ## Visualizing to see its relationship with other categorial features

# %%
plt.figure(figsize = (17,7))
sns.barplot(x = train.tax_liens, y = 'credit_score', data = train)

# %%
plt.figure(figsize = (17,7))
sns.barplot(x = train.term, y = 'credit_score', hue = train.years_in_current_job,data = train)

# %%
plt.figure(figsize = (17,7))
sns.barplot(x = 'years_in_current_job', y = 'credit_score', hue = train.tax_liens,data = train)

# %%
plt.figure(figsize = (17,7))
sns.barplot(x = 'home_ownership', y = 'credit_score', data = train)

# %%
plt.figure(figsize = (17,7))
sns.barplot(x = train.bankruptcies, y = 'credit_score',data = train)

# %%
plt.figure(figsize = (20,8))
sns.boxplot(x = train.credit_score, y = train.years_in_current_job 	, data = train)

# %%
plt.figure(figsize = (17,7))
sns.barplot(x = train.number_of_credit_problems, y = 'credit_score', data = train)

# %%
train.credit_score.value_counts(dropna = False)
# Out:
# NaN       1555
# 740.0      169
# 747.0      168
# 748.0      157
# 745.0      152
#           ...
# 602.0        1
# 616.0        1
# 585.0        1
# 620.0        1
# 7010.0       1
# Name: credit_score, Length: 269, dtype: int64

# %%
mean_score2 = train.groupby('purpose')['credit_score']

mean_score2.agg(np.median)             # Since value are close so using this
# Out:
# purpose
# business loan           724.5
# buy a car               739.0
# buy house               718.0
# debt consolidation      732.0
# educational expenses    735.0
# home improvements       734.0
# major purchase          736.5
# medical bills           719.5
# moving                  728.0
# other                   726.0
# small business          723.0
# take a trip             709.0
# vacation                732.0
# wedding                 728.5
# Name: credit_score, dtype: float64

# %%
train.credit_score = pd.Series(mean_score2.transform(lambda x : x.fillna(value = x.median())))

# Since one category has no values in barchart hence using ffill to fill it
#train.credit_score.fillna(method = 'ffill', inplace = True)

# Checking for NaN values present

print('Total NaN values present after filling :: ', train.credit_score.isna().sum())
# Out:
# Total NaN values present after filling ::  0

# %%
#Displaying values

train.credit_score.value_counts(dropna = False)
# Out:
# 732.0     1341
# 726.0      219
# 734.0      208
# 740.0      169
# 747.0      168
#           ...
# 6880.0       1
# 6830.0       1
# 6780.0       1
# 599.0        1
# 6670.0       1
# Name: credit_score, Length: 272, dtype: int64

# %%
# Checking for NaN values

train.agg(lambda x : x.isna().sum())
# Out:
# home_ownership                  0
# annual_income                   0
# years_in_current_job            0
# tax_liens                       0
# number_of_open_accounts         0
# years_of_credit_history         0
# maximum_open_credit             0
# number_of_credit_problems       0
# months_since_last_delinquent    0
# bankruptcies                    0
# purpose                         0
# term                            0
# current_loan_amount             0
# current_credit_balance          0
# monthly_debt                    0
# credit_score                    0
# credit_default                  0
# dtype: int64

# %%
train_int_cols = list(train.select_dtypes(include = np.number).columns)
train_obj_cols = list(train.select_dtypes(include = np.object).columns)

# %% [markdown]
# # Data Visualization for Outliers ::

# %%
# Plotting all int/float columns boxplot

plt.figure(figsize = (20,15))
sns.boxplot(data = train[train_int_cols], orient = 'h')

# %% [markdown]
# - Maimum Open credit has some outliers hence treating it first

# %% [markdown]
# - Since the some values seems to be an outlier hence taking log of all values
# - Since some values in column are zero hence adding 1 to every value since log(1) == 0
# - Also taking first those columns that have big values in respective columns

# %% [markdown]
# ### Since target variable is also present in integer columns hence dropping it before transfoming the values.

# %%
train_int_cols
# Out:
# ['annual_income',
#  'tax_liens',
#  'number_of_open_accounts',
#  'years_of_credit_history',
#  'maximum_open_credit',
#  'number_of_credit_problems',
#  'months_since_last_delinquent',
#  'bankruptcies',
#  'current_loan_amount',
#  'current_credit_balance',
#  'monthly_debt',
#  'credit_score',
#  'credit_default']

# %%
# dropping last item
train_int_cols_temp = train_int_cols[ :-1]
train_int_cols_temp

train[train_int_cols_temp]= train[train_int_cols_temp].transform(lambda x : np.log(x + 1))
train[train_int_cols_temp].isna().sum()
# Out:
# annual_income                   0
# tax_liens                       0
# number_of_open_accounts         0
# years_of_credit_history         0
# maximum_open_credit             0
# number_of_credit_problems       0
# months_since_last_delinquent    0
# bankruptcies                    0
# current_loan_amount             0
# current_credit_balance          0
# monthly_debt                    0
# credit_score                    0
# dtype: int64

# %%
# Plotting all int/float columns boxplot

plt.figure(figsize = (20,15))
sns.boxplot(data = train[train_int_cols], orient = 'h')

# %%
cols = ['annual_income', 'maximum_open_credit', 'current_loan_amount', 'current_credit_balance', 'monthly_debt']

train[cols].plot(kind = 'box', figsize = (20,15))

# %%
train[train_int_cols].describe().T
# Out:
#                                count       mean       std        min  \
# annual_income                 7498.0  13.981518  0.469980  12.011261
# tax_liens                     7498.0   0.016480  0.130220   0.000000
# number_of_open_accounts       7498.0   2.416995  0.401702   1.098612
# years_of_credit_history       7498.0   2.897742  0.356699   1.609438
# maximum_open_credit           7498.0  12.954924  1.473981   0.000000
# number_of_credit_problems     7498.0   0.106553  0.278957   0.000000
# months_since_last_delinquent  7498.0   3.424837  0.563033   0.000000
# bankruptcies                  7498.0   0.080978  0.231394   0.000000
# current_loan_amount           7498.0  13.137166  2.016867   9.327501
# current_credit_balance        7498.0  12.072942  1.457326   0.000000
# monthly_debt                  7498.0   9.582254  0.796547   0.000000
# credit_score                  7498.0   6.706074  0.514797   6.373320
# credit_default                7498.0   0.281542  0.449781   0.000000
#
#                                     25%        50%        75%        max
# annual_income                 13.734537  13.960048  14.226319  16.132920
# tax_liens                      0.000000   0.000000   0.000000   2.079442
# number_of_open_accounts        2.197225   2.397895   2.708050   3.784190
# years_of_credit_history        2.674149   2.890372   3.126761   4.072440
# maximum_open_credit           12.539891  13.077747  13.584392  20.989259
# number_of_credit_problems      0.000000   0.000000   0.000000   2.079442
# months_since_last_delinquent   3.465736   3.465736   3.647390   4.779123
# bankruptcies                   0.000000   0.000000   0.000000   1.609438
# current_loan_amount           12.101748  12.643059  13.162036  18.420681
# current_credit_balance        11.646418  12.251729  12.795069  15.688358
# monthly_debt                   9.217564   9.685394  10.078742  11.825398
# credit_score                   6.577861   6.597146   6.608001   8.924124
# credit_default                 0.000000   0.000000   1.000000   1.000000

# %% [markdown]
# - Seems that all values have been taken care of. Now proceeding further

# %%
train[train_obj_cols].isna().sum()
# Out:
# home_ownership          0
# years_in_current_job    0
# purpose                 0
# term                    0
# dtype: int64

# %%
dummy = pd.get_dummies(train[train_obj_cols])
dummy.T
# Out:
# Id                              0     1     2     3     4     5     6     \
# home_ownership_Have Mortgage       0     0     0     0     0     0     0
# home_ownership_Home Mortgage       0     0     1     0     0     0     1
# home_ownership_Own Home            1     1     0     1     0     0     0
# home_ownership_Rent                0     0     0     0     1     1     0
# years_in_current_job_1 year        0     0     0     0     0     0     0
# years_in_current_job_10+ years     1     1     0     0     0     0     1
# years_in_current_job_2 years       0     0     0     0     0     0     0
# years_in_current_job_3 years       0     0     0     0     0     0     0
# years_in_current_job_4 years       0     0     0     0     0     0     0
# years_in_current_job_5 years       0     0     0     0     0     0     0
# years_in_current_job_6 years       0     0     0     1     0     0     0
# years_in_current_job_7 years       0     0     0     0     0     1     0
# years_in_current_job_8 years       0     0     1     0     1     0     0
# years_in_current_job_9 years       0     0     0     0     0     0     0
# years_in_current_job_< 1 year      0     0     0     0     0     0     0
# purpose_business loan              0     0     0     0     0     0     0
# purpose_buy a car                  0     0     0     0     0     0     0
# purpose_buy house                  0     0     0     0     0     0     0
# purpose_debt consolidation         1     1     1     1     1     0     0
# purpose_educational expenses       0     0     0     0     0     0     0
# purpose_home improvements          0     0     0     0     0     0     1
# purpose_major purchase             0     0     0     0     0     0     0
# purpose_medical bills              0     0     0     0     0     0     0
# purpose_moving                     0     0     0     0     0     0     0
# purpose_other                      0     0     0     0     0     1     0
# purpose_small business             0     0     0     0     0     0     0
# purpose_take a trip                0     0     0     0     0     0     0
# purpose_vacation                   0     0     0     0     0     0     0
# purpose_wedding                    0     0     0     0     0     0     0
# term_Long Term                     0     1     0     0     0     1     0
# term_Short Term                    1     0     1     1     1     0     1
#
# Id                              7     8     9     ...  7490  7491  7492  7493  \
# home_ownership_Have Mortgage       0     0     0  ...     0     0     0     0
# home_ownership_Home Mortgage       0     1     1  ...     0     1     1     0
# home_ownership_Own Home            0     0     0  ...     1     0     0     0
# home_ownership_Rent                1     0     0  ...     0     0     0     1
# years_in_current_job_1 year        0     0     1  ...     0     0     0     0
# years_in_current_job_10+ years     1     0     0  ...     1     0     1     0
# years_in_current_job_2 years       0     0     0  ...     0     0     0     0
# years_in_current_job_3 years       0     0     0  ...     0     0     0     0
# years_in_current_job_4 years       0     0     0  ...     0     0     0     0
# years_in_current_job_5 years       0     1     0  ...     0     0     0     0
# years_in_current_job_6 years       0     0     0  ...     0     1     0     0
# years_in_current_job_7 years       0     0     0  ...     0     0     0     0
# years_in_current_job_8 years       0     0     0  ...     0     0     0     1
# years_in_current_job_9 years       0     0     0  ...     0     0     0     0
# years_in_current_job_< 1 year      0     0     0  ...     0     0     0     0
# purpose_business loan              0     0     0  ...     0     0     0     0
# purpose_buy a car                  0     0     0  ...     0     0     0     0
# purpose_buy house                  0     0     0  ...     0     0     0     0
# purpose_debt consolidation         0     0     1  ...     1     1     1     1
# purpose_educational expenses       0     0     0  ...     0     0     0     0
# purpose_home improvements          0     1     0  ...     0     0     0     0
# purpose_major purchase             0     0     0  ...     0     0     0     0
# purpose_medical bills              0     0     0  ...     0     0     0     0
# purpose_moving                     0     0     0  ...     0     0     0     0
# purpose_other                      1     0     0  ...     0     0     0     0
# purpose_small business             0     0     0  ...     0     0     0     0
# purpose_take a trip                0     0     0  ...     0     0     0     0
# purpose_vacation                   0     0     0  ...     0     0     0     0
# purpose_wedding                    0     0     0  ...     0     0     0     0
# term_Long Term                     0     0     1  ...     0     0     0     1
# term_Short Term                    1     1     0  ...     1     1     1     0
#
# Id                              7494  7495  7496  7497  7498  7499
# home_ownership_Have Mortgage       0     0     0     0     0     0
# home_ownership_Home Mortgage       0     0     1     0     1     0
# home_ownership_Own Home            1     0     0     0     0     0
# home_ownership_Rent                0     1     0     1     0     1
# years_in_current_job_1 year        0     0     1     0     0     0
# years_in_current_job_10+ years     0     0     0     0     0     0
# years_in_current_job_2 years       0     0     0     0     0     0
# years_in_current_job_3 years       0     0     0     0     0     0
# years_in_current_job_4 years       0     0     0     0     0     1
# years_in_current_job_5 years       0     0     0     0     0     0
# years_in_current_job_6 years       0     0     0     1     1     0
# years_in_current_job_7 years       0     0     0     0     0     0
# years_in_current_job_8 years       0     0     0     0     0     0
# years_in_current_job_9 years       0     0     0     0     0     0
# years_in_current_job_< 1 year      1     1     0     0     0     0
# purpose_business loan              0     0     0     0     0     0
# purpose_buy a car                  0     0     0     1     0     0
# purpose_buy house                  0     0     0     0     0     0
# purpose_debt consolidation         1     0     1     0     1     1
# purpose_educational expenses       0     0     0     0     0     0
# purpose_home improvements          0     0     0     0     0     0
# purpose_major purchase             0     0     0     0     0     0
# purpose_medical bills              0     0     0     0     0     0
# purpose_moving                     0     0     0     0     0     0
# purpose_other                      0     1     0     0     0     0
# purpose_small business             0     0     0     0     0     0
# purpose_take a trip                0     0     0     0     0     0
# purpose_vacation                   0     0     0     0     0     0
# purpose_wedding                    0     0     0     0     0     0
# term_Long Term                     0     0     1     0     0     0
# term_Short Term                    1     1     0     1     1     1
#
# [31 rows x 7498 columns]

# %%
train_final = pd.concat([train[train_int_cols], dummy], axis = 1)
train_final
# Out:
#       annual_income  tax_liens  number_of_open_accounts  \
# Id
# 0         13.085882        0.0                 2.484907
# 1         13.840679        0.0                 2.772589
# 2         13.529711        0.0                 2.484907
# 3         13.598683        0.0                 2.197225
# 4         13.562249        0.0                 2.639057
# ...             ...        ...                      ...
# 7495      12.904687        0.0                 1.386294
# 7496      14.243379        0.0                 2.397895
# 7497      14.446203        0.0                 2.564949
# 7498      13.950532        0.0                 3.091042
# 7499      13.950432        0.0                 2.197225
#
#       years_of_credit_history  maximum_open_credit  number_of_credit_problems  \
# Id
# 0                    3.306887            13.438576                   0.693147
# 1                    2.791165            13.982491                   0.000000
# 2                    3.583519            13.983086                   0.000000
# 3                    3.157000            11.900912                   0.693147
# 4                    2.681022            12.863170                   0.693147
# ...                       ...                  ...                        ...
# 7495                 2.251292            11.588654                   0.000000
# 7496                 3.314186            13.439089                   0.000000
# 7497                 3.499533            14.391518                   0.000000
# 7498                 3.314186            13.947636                   0.000000
# 7499                 2.341806            13.083275                   0.000000
#
#       months_since_last_delinquent  bankruptcies  current_loan_amount  \
# Id
# 0                         3.850148      0.693147            18.420681
# 1                         3.465736      0.000000            12.487368
# 2                         3.465736      0.000000            18.420681
# 3                         3.850148      0.693147            11.706821
# 4                         3.496508      0.000000            11.742774
# ...                            ...           ...                  ...
# 7495                      3.465736      0.000000            11.770362
# 7496                      3.784190      0.000000            13.003690
# 7497                      3.465736      0.000000            18.420681
# 7498                      3.465736      0.000000            13.329825
# 7499                      3.465736      0.000000            10.200959
#
#       current_credit_balance  ...  purpose_major purchase  \
# Id                            ...
# 0                  10.766103  ...                       0
# 1                  12.886573  ...                       0
# 2                  12.639120  ...                       0
# 3                  11.470602  ...                       0
# 4                  11.443683  ...                       0
# ...                      ...  ...                     ...
# 7495               11.204945  ...                       0
# 7496               13.031125  ...                       0
# 7497               13.076975  ...                       0
# 7498               13.073310  ...                       0
# 7499               12.571386  ...                       0
#
#       purpose_medical bills  purpose_moving  purpose_other  \
# Id
# 0                         0               0              0
# 1                         0               0              0
# 2                         0               0              0
# 3                         0               0              0
# 4                         0               0              0
# ...                     ...             ...            ...
# 7495                      0               0              1
# 7496                      0               0              0
# 7497                      0               0              0
# 7498                      0               0              0
# 7499                      0               0              0
#
#       purpose_small business  purpose_take a trip  purpose_vacation  \
# Id
# 0                          0                    0                 0
# 1                          0                    0                 0
# 2                          0                    0                 0
# 3                          0                    0                 0
# 4                          0                    0                 0
# ...                      ...                  ...               ...
# 7495                       0                    0                 0
# 7496                       0                    0                 0
# 7497                       0                    0                 0
# 7498                       0                    0                 0
# 7499                       0                    0                 0
#
#       purpose_wedding  term_Long Term  term_Short Term
# Id
# 0                   0               0                1
# 1                   0               1                0
# 2                   0               0                1
# 3                   0               0                1
# 4                   0               0                1
# ...               ...             ...              ...
# 7495                0               0                1
# 7496                0               1                0
# 7497                0               0                1
# 7498                0               0                1
# 7499                0               0                1
#
# [7498 rows x 44 columns]

# %% [markdown]
# # Making Models ::

# %%
x = train_final.drop('credit_default', axis = 1)
y = train_final.credit_default

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 100)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble  import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
model_dt = DecisionTreeClassifier(random_state = 10)
model_rf = RandomForestClassifier(random_state = 11)
model_knn = KNeighborsClassifier(n_neighbors = 10, n_jobs = -1)
#model_lr = LogisticRegression(random_state = 12)
model_nb = GaussianNB()
model_svc = SVC(random_state = 14)

# %%
train_final.credit_default.value_counts()
# Out:
# 0    5387
# 1    2111
# Name: credit_default, dtype: int64

# %%
from sklearn.metrics import accuracy_score, classification_report

score_values = []
def modelling(models, x_train, y_train, x_test, y_test):
    for model in models:
        model.fit(x_train, y_train)
        predict = model.predict(x_test)
        score = accuracy_score(y_test, predict)
        score_values.append(score)
        print(f"Accurace score of {model} is :: ", score)
        print(f"Classification Report is :: \n")
        print(classification_report(y_test, predict))
        print('*' * 90)

        
# using the function

models = [model_dt, model_knn, model_nb, model_rf, model_svc]
modelling(models, x_train, y_train, x_test, y_test)
# Out:
# Accurace score of DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=10, splitter='best') is ::  0.6926666666666667
# Classification Report is ::
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78      1068
#            1       0.47      0.52      0.49       432
#
#     accuracy                           0.69      1500
#    macro avg       0.63      0.64      0.64      1500
# weighted avg       0.70      0.69      0.70      1500
#
# ******************************************************************************************
# Accurace score of KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=10, p=2,
#                      weights='uniform') is ::  0.76
# Classification Report is ::
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.96      0.85      1068
#            1       0.74      0.26      0.38       432
#
#     accuracy                           0.76      1500
#    macro avg       0.75      0.61      0.62      1500
# weighted avg       0.76      0.76      0.72      1500
#
# ******************************************************************************************
# Accurace score of GaussianNB(priors=None, var_smoothing=1e-09) is ::  0.7533333333333333
# Classification Report is ::
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84      1068
#            1       0.62      0.36      0.46       432
#
#     accuracy                           0.75      1500
#    macro avg       0.70      0.64      0.65      1500
# weighted avg       0.73      0.75      0.73      1500
#
# ******************************************************************************************
# Accurace score of RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=11, verbose=0,
#                        warm_start=False) is ::  0.7646666666666667
# Classification Report is ::
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.96      0.85      1068
#            1       0.75      0.27      0.40       432
#
#     accuracy                           0.76      1500
#    macro avg       0.76      0.62      0.63      1500
# weighted avg       0.76      0.76      0.72      1500
#
# ******************************************************************************************
# Accurace score of SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=14, shrinking=True, tol=0.001,
#     verbose=False) is ::  0.766
# Classification Report is ::
#
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86      1068
#            1       1.00      0.19      0.32       432
#
#     accuracy                           0.77      1500
#    macro avg       0.88      0.59      0.59      1500
# weighted avg       0.82      0.77      0.70      1500
#
# ******************************************************************************************

# %% [markdown]
# ## Observation ::
#
# - SVC and RandomForest have same accuracy = 77%
# - naive Bayes have accuracy = 75%
# - Knn have accuracy = 76%
# - Decision Tree have accuracy = 69%

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# calculating log probabilities of models used

prob_dt = model_dt.predict_proba(x_test)
prob_rf = model_rf.predict_proba(x_test)
prob_knn = model_knn.predict_proba(x_test)
prob_nb = model_nb.predict_proba(x_test)

# %%
# Keep Probabilities of the positive class only.

prob_dt = prob_dt[:, 1]
prob_rf = prob_rf[:, 1]
prob_knn = prob_knn[:, 1]
prob_nb = prob_nb[:, 1]

# %%
# Calculating the auc score and displaying it

auc_dt = roc_auc_score(y_test, prob_dt)
auc_rf = roc_auc_score(y_test, prob_rf)
auc_knn = roc_auc_score(y_test, prob_knn)
auc_nb = roc_auc_score(y_test, prob_nb)

print('ROC- AUC Score for Decision Tree is :: %0.3f'%auc_dt)
print('ROC- AUC Score for Random Forest is :: %0.3f'%auc_rf)
print('ROC- AUC Score for KNN is :: %0.3f'%auc_knn)
print('ROC- AUC Score for Niave Bayes is :: %0.3f'%auc_nb)
# Out:
# ROC- AUC Score for Decision Tree is :: 0.641
# ROC- AUC Score for Random Forest is :: 0.758
# ROC- AUC Score for KNN is :: 0.726
# ROC- AUC Score for Niave Bayes is :: 0.735

# %%
# Getting the ROC Curve.

fpr_dt, tpr_dt, threshold_dt = roc_curve(y_test, prob_dt)
fpr_rf, tpr_rf, threshold_rf = roc_curve(y_test, prob_rf)
fpr_knn, tpr_knn, threshold_knn = roc_curve(y_test, prob_knn)
fpr_nb, tpr_nb, threshold_nb = roc_curve(y_test, prob_nb)

# %%
# Plotting the ROC Curve for all models 

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize = (15,7))
plt.plot(fpr_dt, tpr_dt, linewidth = 2, linestyle = 'dotted', label = 'Decision Tree')
plt.plot(fpr_rf, tpr_rf, linewidth = 2, linestyle = 'dashdot', label = 'Random Forest')
plt.plot(fpr_knn, tpr_knn, linewidth = 2, linestyle = 'dashed', label = 'K-Neighbours')
plt.plot(fpr_nb, tpr_nb, linewidth = 2, linestyle = '-', label = 'Naive Bayes')

plt.title('Receiver Operating Characteristic Curve (ROC AUC) Curve', fontsize = 25)
plt.xlabel('False Positive Rate', fontsize = 20)
plt.ylabel('True Positive Rate', fontsize = 20)
plt.legend(fontsize = 16)
plt.show()

# %% [markdown]
# # Performing actions on Test Data ::

# %% [markdown]
# ---
# # Missing Values Imputation ::

# %% [markdown]
# ## Filling missing values of 'bankruptcies' column

# %%
from scipy.stats import mode

# Filling with mode value

test.bankruptcies =  test.bankruptcies.agg(lambda x : x.fillna(value = mode(x).mode[0]))

# Checking for NaN values present

print('Total NaN values present after filling :: ', test.bankruptcies.isna().sum())
# Out:
# Total NaN values present after filling ::  0

# %% [markdown]
# ## Filling missing values of 'months_since_last_delinquent' column

# %%
# Checking values before the filled values 

test['months_since_last_delinquent'].value_counts(dropna = False)
# Out:
# NaN     1358
# 16.0      30
# 23.0      28
# 14.0      28
# 24.0      26
#         ...
# 60.0       5
# 81.0       5
# 64.0       5
# 65.0       5
# 82.0       3
# Name: months_since_last_delinquent, Length: 84, dtype: int64

# %%
# Grouping months_since_last_delinquent columns as per  'purpose', 'home_ownership'

mean_score_t = test.groupby(['purpose', 'home_ownership'])['months_since_last_delinquent']
mean_score_t.agg([np.median])
# Out:
#                                      median
# purpose              home_ownership
# business loan        Home Mortgage     34.0
#                      Own Home          33.0
#                      Rent              51.5
# buy a car            Home Mortgage     21.0
#                      Own Home          46.0
#                      Rent              24.5
# buy house            Home Mortgage     20.5
#                      Own Home          47.0
#                      Rent              36.5
# debt consolidation   Home Mortgage     28.0
#                      Own Home          28.5
#                      Rent              32.0
# educational expenses Rent               8.0
# home improvements    Home Mortgage     25.5
#                      Own Home          41.0
#                      Rent              21.5
# major purchase       Home Mortgage     16.0
#                      Own Home           NaN
#                      Rent              82.0
# medical bills        Home Mortgage     10.0
#                      Own Home           NaN
#                      Rent              27.0
# moving               Rent              14.0
# other                Home Mortgage     34.5
#                      Own Home          24.0
#                      Rent              37.0
# small business       Own Home           NaN
#                      Rent              48.5
# take a trip          Have Mortgage     39.0
#                      Own Home           NaN
#                      Rent              45.0
# vacation             Rent              25.0
# wedding              Home Mortgage     56.0
#                      Rent              36.0

# %%
test.loc[: , 'months_since_last_delinquent'] = mean_score_t.transform(lambda x : x.fillna(x.median()))

#Using ffill to fill any left missing value

test.months_since_last_delinquent = test.months_since_last_delinquent.fillna(method = 'ffill')
# Checking for NaN values present

print('Total NaN values present after filling :: ', test.months_since_last_delinquent.isna().sum())
# Out:
# Total NaN values present after filling ::  0

# %% [markdown]
# ## Filling 'years_in_current_job'  column ::

# %%
print('Total NaN values present before filling :: ', test.years_in_current_job.isna().sum())

# Displaying total unique values present 

test.years_in_current_job.value_counts(dropna = False)
# Out:
# Total NaN values present before filling ::  86
# 10+ years    810
# 3 years      228
# 2 years      212
# < 1 year     207
# 5 years      169
# 1 year       153
# 4 years      152
# 7 years      140
# 6 years      137
# 8 years      107
# 9 years       99
# NaN           86
# Name: years_in_current_job, dtype: int64

# %%
### Since NaN values present hence filling it using ffill and bfill 

test.years_in_current_job.fillna(method = 'ffill', inplace = True)
test.years_in_current_job.fillna(method = 'bfill', inplace = True)


# Checking for NaN values present
print('Total NaN values present after filling :: ', test.years_in_current_job.isna().sum())

test.years_in_current_job.value_counts(dropna = False)
# Out:
# Total NaN values present after filling ::  0
# 10+ years    837
# 3 years      232
# 2 years      220
# < 1 year     218
# 5 years      177
# 1 year       160
# 4 years      159
# 7 years      145
# 6 years      139
# 8 years      110
# 9 years      103
# Name: years_in_current_job, dtype: int64

# %% [markdown]
# ## Filling missing values of Annual Income column
#
# - Annual Income and Monthly debt are highly correlated :: 0.58
# - Annual Income and Current credti balance also related :: 0.38
# - So considering both columns to fill missing values of annual income column

# %% [markdown]
# ## Filling 'annual_income' column ::

# %%
# Displaying total unique values

test.annual_income.value_counts(dropna = False)
# Out:
# NaN          513
# 1328803.0      3
# 1237109.0      3
# 1025145.0      3
# 1214993.0      3
#             ...
# 641687.0       1
# 2304624.0      1
# 985758.0       1
# 1389888.0      1
# 1486845.0      1
# Name: annual_income, Length: 1930, dtype: int64

# %%
#tranforming/applying mean values to corresponding rows with missing values

test.annual_income = test.groupby('years_in_current_job')['annual_income'].transform(lambda x : x.fillna(x.mean()))

# Checking for NaN values present

print('Total NaN values present after filling :: ', test.annual_income.isna().sum())

#Displaying values

test.annual_income.value_counts(dropna = False)
# Out:
# Total NaN values present after filling ::  0
# 1.474319e+06    179
# 1.312493e+06     53
# 1.282024e+06     48
# 1.437687e+06     39
# 1.121114e+06     33
#                ...
# 6.416870e+05      1
# 2.304624e+06      1
# 9.857580e+05      1
# 1.389888e+06      1
# 1.835495e+06      1
# Name: annual_income, Length: 1940, dtype: int64

# %% [markdown]
# ## Filling 'credit_score' column ::

# %%
# Displaying total unique values

test.credit_score.value_counts(dropna = False)
# Out:
# NaN       513
# 746.0      56
# 739.0      55
# 741.0      54
# 740.0      50
#          ...
# 6850.0      1
# 6310.0      1
# 6150.0      1
# 6840.0      1
# 6670.0      1
# Name: credit_score, Length: 212, dtype: int64

# %%
mean_score_t2 = test.groupby('purpose')['credit_score']

mean_score_t2.agg(np.median)             # Since value are close so using this
# Out:
# purpose
# business loan            715.0
# buy a car                739.0
# buy house                740.0
# debt consolidation       732.0
# educational expenses     735.0
# home improvements        738.0
# major purchase           734.5
# medical bills            714.5
# moving                   722.0
# other                    720.0
# small business           716.0
# take a trip              723.0
# vacation                4030.0
# wedding                  729.5
# Name: credit_score, dtype: float64

# %%
test.credit_score = mean_score_t2.transform(lambda x : x.fillna(value = x.median()))

# Since one category has no values in barchart hence using ffill to fill it
#train.credit_score.fillna(method = 'ffill', inplace = True)

# Checking for NaN values present

print('Total NaN values present after filling :: ', test.credit_score.isna().sum())
# Out:
# Total NaN values present after filling ::  0

# %%
#Displaying values

test.credit_score.value_counts(dropna = False)
# Out:
# 732.0     433
# 738.0      77
# 720.0      72
# 739.0      60
# 746.0      56
#          ...
# 648.0       1
# 585.0       1
# 6770.0      1
# 629.0       1
# 6670.0      1
# Name: credit_score, Length: 214, dtype: int64

# %%
# Checking for NaN values

test.agg(lambda x : x.isna().sum())
# Out:
# home_ownership                  0
# annual_income                   0
# years_in_current_job            0
# tax_liens                       0
# number_of_open_accounts         0
# years_of_credit_history         0
# maximum_open_credit             0
# number_of_credit_problems       0
# months_since_last_delinquent    0
# bankruptcies                    0
# purpose                         0
# term                            0
# current_loan_amount             0
# current_credit_balance          0
# monthly_debt                    0
# credit_score                    0
# dtype: int64

# %%
test_int_cols = list(test.select_dtypes(include = np.number).columns)
test_obj_cols = list(test.select_dtypes(include = np.object).columns)

# %% [markdown]
# # Data Visualization for Outliers ::

# %%
# Plotting all int/float columns boxplot

plt.figure(figsize = (20,15))
sns.boxplot(data = test[test_int_cols], orient = 'h')

# %% [markdown]
# - Maimum Open credit has some outliers hence treating it first

# %% [markdown]
# - Since the some values seems to be an outlier hence taking log of all values
# - Since some values in column are zero hence adding 1 to every value since log(1) == 0
# - Also taking first those columns that have big values in respective columns

# %% [markdown]
# ### Since target variable is also present in integer columns hence dropping it before transfoming the values.

# %%
test_int_cols
# Out:
# ['annual_income',
#  'tax_liens',
#  'number_of_open_accounts',
#  'years_of_credit_history',
#  'maximum_open_credit',
#  'number_of_credit_problems',
#  'months_since_last_delinquent',
#  'bankruptcies',
#  'current_loan_amount',
#  'current_credit_balance',
#  'monthly_debt',
#  'credit_score']

# %%
test[test_int_cols]= test[test_int_cols].transform(lambda x : np.log(x + 1))
test[test_int_cols].isna().sum()
# Out:
# annual_income                   0
# tax_liens                       0
# number_of_open_accounts         0
# years_of_credit_history         0
# maximum_open_credit             0
# number_of_credit_problems       0
# months_since_last_delinquent    0
# bankruptcies                    0
# current_loan_amount             0
# current_credit_balance          0
# monthly_debt                    0
# credit_score                    0
# dtype: int64

# %%
# Plotting all int/float columns boxplot

plt.figure(figsize = (20,15))
sns.boxplot(data = test[test_int_cols], orient = 'h')

# %%
test[test_int_cols].describe().T
# Out:
#                                count       mean       std        min  \
# annual_income                 2500.0  14.013922  0.473879  11.576219
# tax_liens                     2500.0   0.018476  0.135671   0.000000
# number_of_open_accounts       2500.0   2.423478  0.396745   0.693147
# years_of_credit_history       2500.0   2.894000  0.369580   1.589235
# maximum_open_credit           2500.0  12.994171  1.295934   0.000000
# number_of_credit_problems     2500.0   0.099709  0.272502   0.000000
# months_since_last_delinquent  2500.0   3.366843  0.579274   0.000000
# bankruptcies                  2500.0   0.070817  0.219771   0.000000
# current_loan_amount           2500.0  13.160381  2.038625   9.643615
# current_credit_balance        2500.0  12.078340  1.360687   0.000000
# monthly_debt                  2500.0   9.574137  0.796664   4.543295
# credit_score                  2500.0   6.730567  0.561210   6.373320
#
#                                     25%        50%        75%        max
# annual_income                 13.749972  14.079313  14.213432  16.521934
# tax_liens                      0.000000   0.000000   0.000000   2.772589
# number_of_open_accounts        2.197225   2.397895   2.708050   3.891820
# years_of_credit_history        2.667228   2.890372   3.139833   3.996364
# maximum_open_credit           12.537486  13.078781  13.595611  17.813425
# number_of_credit_problems      0.000000   0.000000   0.000000   2.772589
# months_since_last_delinquent   3.295837   3.384390   3.569533   4.418841
# bankruptcies                   0.000000   0.000000   0.000000   1.791759
# current_loan_amount           12.139545  12.683446  13.166538  18.420681
# current_credit_balance        11.609284  12.242337  12.811343  15.612272
# monthly_debt                   9.212912   9.719775  10.091915  11.446315
# credit_score                   6.576470   6.597146   6.609349   8.920122

# %% [markdown]
# - Seems that all values have been taken care of. Now proceeding further

# %%
test[test_obj_cols].isna().sum()
# Out:
# home_ownership          0
# years_in_current_job    0
# purpose                 0
# term                    0
# dtype: int64

# %%
dummy_t = pd.get_dummies(test[test_obj_cols])
dummy_t.T
# Out:
# Id                              7500  7501  7502  7503  7504  7505  7506  \
# home_ownership_Have Mortgage       0     0     0     0     0     0     0
# home_ownership_Home Mortgage       0     0     1     1     1     1     1
# home_ownership_Own Home            0     0     0     0     0     0     0
# home_ownership_Rent                1     1     0     0     0     0     0
# years_in_current_job_1 year        0     1     0     0     0     0     0
# years_in_current_job_10+ years     0     0     0     1     0     0     0
# years_in_current_job_2 years       0     0     0     0     0     0     0
# years_in_current_job_3 years       0     0     1     0     0     0     1
# years_in_current_job_4 years       1     0     0     0     0     0     0
# years_in_current_job_5 years       0     0     0     0     0     1     0
# years_in_current_job_6 years       0     0     0     0     1     0     0
# years_in_current_job_7 years       0     0     0     0     0     0     0
# years_in_current_job_8 years       0     0     0     0     0     0     0
# years_in_current_job_9 years       0     0     0     0     0     0     0
# years_in_current_job_< 1 year      0     0     0     0     0     0     0
# purpose_business loan              0     0     0     0     0     0     0
# purpose_buy a car                  0     0     0     0     0     0     0
# purpose_buy house                  0     0     0     0     0     0     0
# purpose_debt consolidation         1     0     1     1     1     1     0
# purpose_educational expenses       0     1     0     0     0     0     0
# purpose_home improvements          0     0     0     0     0     0     1
# purpose_major purchase             0     0     0     0     0     0     0
# purpose_medical bills              0     0     0     0     0     0     0
# purpose_moving                     0     0     0     0     0     0     0
# purpose_other                      0     0     0     0     0     0     0
# purpose_small business             0     0     0     0     0     0     0
# purpose_take a trip                0     0     0     0     0     0     0
# purpose_vacation                   0     0     0     0     0     0     0
# purpose_wedding                    0     0     0     0     0     0     0
# term_Long Term                     0     0     0     0     1     0     0
# term_Short Term                    1     1     1     1     0     1     1
#
# Id                              7507  7508  7509  ...  9990  9991  9992  9993  \
# home_ownership_Have Mortgage       0     0     0  ...     0     0     0     0
# home_ownership_Home Mortgage       0     0     1  ...     1     0     1     0
# home_ownership_Own Home            0     0     0  ...     0     0     0     0
# home_ownership_Rent                1     1     0  ...     0     1     0     1
# years_in_current_job_1 year        0     0     0  ...     0     0     0     0
# years_in_current_job_10+ years     0     0     1  ...     1     0     0     1
# years_in_current_job_2 years       0     0     0  ...     0     1     0     0
# years_in_current_job_3 years       1     0     0  ...     0     0     1     0
# years_in_current_job_4 years       0     0     0  ...     0     0     0     0
# years_in_current_job_5 years       0     1     0  ...     0     0     0     0
# years_in_current_job_6 years       0     0     0  ...     0     0     0     0
# years_in_current_job_7 years       0     0     0  ...     0     0     0     0
# years_in_current_job_8 years       0     0     0  ...     0     0     0     0
# years_in_current_job_9 years       0     0     0  ...     0     0     0     0
# years_in_current_job_< 1 year      0     0     0  ...     0     0     0     0
# purpose_business loan              0     0     0  ...     0     0     0     0
# purpose_buy a car                  0     0     0  ...     0     0     0     0
# purpose_buy house                  0     0     0  ...     0     0     0     0
# purpose_debt consolidation         1     0     1  ...     1     0     0     1
# purpose_educational expenses       0     0     0  ...     0     0     0     0
# purpose_home improvements          0     0     0  ...     0     0     0     0
# purpose_major purchase             0     1     0  ...     0     0     0     0
# purpose_medical bills              0     0     0  ...     0     0     0     0
# purpose_moving                     0     0     0  ...     0     0     0     0
# purpose_other                      0     0     0  ...     0     1     1     0
# purpose_small business             0     0     0  ...     0     0     0     0
# purpose_take a trip                0     0     0  ...     0     0     0     0
# purpose_vacation                   0     0     0  ...     0     0     0     0
# purpose_wedding                    0     0     0  ...     0     0     0     0
# term_Long Term                     0     0     0  ...     0     0     0     0
# term_Short Term                    1     1     1  ...     1     1     1     1
#
# Id                              9994  9995  9996  9997  9998  9999
# home_ownership_Have Mortgage       0     0     0     0     0     0
# home_ownership_Home Mortgage       1     1     1     1     0     0
# home_ownership_Own Home            0     0     0     0     0     0
# home_ownership_Rent                0     0     0     0     1     1
# years_in_current_job_1 year        1     0     0     0     0     0
# years_in_current_job_10+ years     0     1     0     0     1     1
# years_in_current_job_2 years       0     0     1     1     0     0
# years_in_current_job_3 years       0     0     0     0     0     0
# years_in_current_job_4 years       0     0     0     0     0     0
# years_in_current_job_5 years       0     0     0     0     0     0
# years_in_current_job_6 years       0     0     0     0     0     0
# years_in_current_job_7 years       0     0     0     0     0     0
# years_in_current_job_8 years       0     0     0     0     0     0
# years_in_current_job_9 years       0     0     0     0     0     0
# years_in_current_job_< 1 year      0     0     0     0     0     0
# purpose_business loan              0     0     0     0     0     0
# purpose_buy a car                  0     0     0     0     0     0
# purpose_buy house                  0     0     0     0     0     0
# purpose_debt consolidation         1     1     1     1     1     1
# purpose_educational expenses       0     0     0     0     0     0
# purpose_home improvements          0     0     0     0     0     0
# purpose_major purchase             0     0     0     0     0     0
# purpose_medical bills              0     0     0     0     0     0
# purpose_moving                     0     0     0     0     0     0
# purpose_other                      0     0     0     0     0     0
# purpose_small business             0     0     0     0     0     0
# purpose_take a trip                0     0     0     0     0     0
# purpose_vacation                   0     0     0     0     0     0
# purpose_wedding                    0     0     0     0     0     0
# term_Long Term                     1     0     0     0     0     1
# term_Short Term                    0     1     1     1     1     0
#
# [31 rows x 2500 columns]

# %%
test_final = pd.concat([test[test_int_cols], dummy_t], axis = 1)
test_final.T
# Out:
# Id                                   7500       7501       7502       7503  \
# annual_income                   14.126752  12.353798  13.957480  14.014619
# tax_liens                        0.000000   0.000000   0.000000   0.000000
# number_of_open_accounts          2.302585   1.945910   2.397895   2.833213
# years_of_credit_history          2.602690   3.517498   2.687847   2.890372
# maximum_open_credit             12.305778  10.932160  12.228817  13.030912
# number_of_credit_problems        0.000000   0.000000   0.000000   0.000000
# months_since_last_delinquent     4.262680   2.197225   3.367296   4.262680
# bankruptcies                     0.000000   0.000000   0.000000   0.000000
# current_loan_amount             11.998255  11.268290  12.206967  12.289416
# current_credit_balance          11.570317  10.737222  11.894719  12.269986
# monthly_debt                     8.826735   7.748891   9.837882  10.224121
# credit_score                     6.597146   6.551080   8.890273   6.606650
# home_ownership_Have Mortgage     0.000000   0.000000   0.000000   0.000000
# home_ownership_Home Mortgage     0.000000   0.000000   1.000000   1.000000
# home_ownership_Own Home          0.000000   0.000000   0.000000   0.000000
# home_ownership_Rent              1.000000   1.000000   0.000000   0.000000
# years_in_current_job_1 year      0.000000   1.000000   0.000000   0.000000
# years_in_current_job_10+ years   0.000000   0.000000   0.000000   1.000000
# years_in_current_job_2 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_3 years     0.000000   0.000000   1.000000   0.000000
# years_in_current_job_4 years     1.000000   0.000000   0.000000   0.000000
# years_in_current_job_5 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_6 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_7 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_8 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_9 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_< 1 year    0.000000   0.000000   0.000000   0.000000
# purpose_business loan            0.000000   0.000000   0.000000   0.000000
# purpose_buy a car                0.000000   0.000000   0.000000   0.000000
# purpose_buy house                0.000000   0.000000   0.000000   0.000000
# purpose_debt consolidation       1.000000   0.000000   1.000000   1.000000
# purpose_educational expenses     0.000000   1.000000   0.000000   0.000000
# purpose_home improvements        0.000000   0.000000   0.000000   0.000000
# purpose_major purchase           0.000000   0.000000   0.000000   0.000000
# purpose_medical bills            0.000000   0.000000   0.000000   0.000000
# purpose_moving                   0.000000   0.000000   0.000000   0.000000
# purpose_other                    0.000000   0.000000   0.000000   0.000000
# purpose_small business           0.000000   0.000000   0.000000   0.000000
# purpose_take a trip              0.000000   0.000000   0.000000   0.000000
# purpose_vacation                 0.000000   0.000000   0.000000   0.000000
# purpose_wedding                  0.000000   0.000000   0.000000   0.000000
# term_Long Term                   0.000000   0.000000   0.000000   0.000000
# term_Short Term                  1.000000   1.000000   1.000000   1.000000
#
# Id                                   7504       7505       7506       7507  \
# annual_income                   14.666069  13.734934  14.025212  14.010969
# tax_liens                        0.000000   0.000000   0.000000   0.000000
# number_of_open_accounts          2.484907   3.295837   2.079442   2.639057
# years_of_credit_history          3.202746   2.917771   3.135494   2.580217
# maximum_open_credit             14.003875  13.477482  12.838463  12.185303
# number_of_credit_problems        0.000000   0.000000   0.000000   0.000000
# months_since_last_delinquent     3.367296   3.737670   3.784190   2.995732
# bankruptcies                     0.000000   0.000000   0.000000   0.000000
# current_loan_amount             13.564013  11.451359  13.026709  12.918353
# current_credit_balance          12.960766  11.816793  12.587604  11.696080
# monthly_debt                    10.659750   9.319105   9.009692   8.935904
# credit_score                     6.561031   6.522093   6.530878   6.553933
# home_ownership_Have Mortgage     0.000000   0.000000   0.000000   0.000000
# home_ownership_Home Mortgage     1.000000   1.000000   1.000000   0.000000
# home_ownership_Own Home          0.000000   0.000000   0.000000   0.000000
# home_ownership_Rent              0.000000   0.000000   0.000000   1.000000
# years_in_current_job_1 year      0.000000   0.000000   0.000000   0.000000
# years_in_current_job_10+ years   0.000000   0.000000   0.000000   0.000000
# years_in_current_job_2 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_3 years     0.000000   0.000000   1.000000   1.000000
# years_in_current_job_4 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_5 years     0.000000   1.000000   0.000000   0.000000
# years_in_current_job_6 years     1.000000   0.000000   0.000000   0.000000
# years_in_current_job_7 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_8 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_9 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_< 1 year    0.000000   0.000000   0.000000   0.000000
# purpose_business loan            0.000000   0.000000   0.000000   0.000000
# purpose_buy a car                0.000000   0.000000   0.000000   0.000000
# purpose_buy house                0.000000   0.000000   0.000000   0.000000
# purpose_debt consolidation       1.000000   1.000000   0.000000   1.000000
# purpose_educational expenses     0.000000   0.000000   0.000000   0.000000
# purpose_home improvements        0.000000   0.000000   1.000000   0.000000
# purpose_major purchase           0.000000   0.000000   0.000000   0.000000
# purpose_medical bills            0.000000   0.000000   0.000000   0.000000
# purpose_moving                   0.000000   0.000000   0.000000   0.000000
# purpose_other                    0.000000   0.000000   0.000000   0.000000
# purpose_small business           0.000000   0.000000   0.000000   0.000000
# purpose_take a trip              0.000000   0.000000   0.000000   0.000000
# purpose_vacation                 0.000000   0.000000   0.000000   0.000000
# purpose_wedding                  0.000000   0.000000   0.000000   0.000000
# term_Long Term                   1.000000   0.000000   0.000000   0.000000
# term_Short Term                  0.000000   1.000000   1.000000   1.000000
#
# Id                                   7508       7509  ...       9990  \
# annual_income                   14.178547  14.576525  ...  14.217279
# tax_liens                        0.000000   0.693147  ...   0.000000
# number_of_open_accounts          2.197225   2.772589  ...   1.791759
# years_of_credit_history          2.312535   2.873565  ...   2.815409
# maximum_open_credit             12.822676  13.673579  ...  13.223538
# number_of_credit_problems        0.000000   0.693147  ...   0.000000
# months_since_last_delinquent     4.418841   2.302585  ...   3.367296
# bankruptcies                     0.000000   0.000000  ...   0.000000
# current_loan_amount             11.790231  12.877324  ...  12.099517
# current_credit_balance          12.378967  12.593038  ...  12.088111
# monthly_debt                     9.221577   9.818637  ...   8.142645
# credit_score                     6.600551   6.614726  ...   6.622736
# home_ownership_Have Mortgage     0.000000   0.000000  ...   0.000000
# home_ownership_Home Mortgage     0.000000   1.000000  ...   1.000000
# home_ownership_Own Home          0.000000   0.000000  ...   0.000000
# home_ownership_Rent              1.000000   0.000000  ...   0.000000
# years_in_current_job_1 year      0.000000   0.000000  ...   0.000000
# years_in_current_job_10+ years   0.000000   1.000000  ...   1.000000
# years_in_current_job_2 years     0.000000   0.000000  ...   0.000000
# years_in_current_job_3 years     0.000000   0.000000  ...   0.000000
# years_in_current_job_4 years     0.000000   0.000000  ...   0.000000
# years_in_current_job_5 years     1.000000   0.000000  ...   0.000000
# years_in_current_job_6 years     0.000000   0.000000  ...   0.000000
# years_in_current_job_7 years     0.000000   0.000000  ...   0.000000
# years_in_current_job_8 years     0.000000   0.000000  ...   0.000000
# years_in_current_job_9 years     0.000000   0.000000  ...   0.000000
# years_in_current_job_< 1 year    0.000000   0.000000  ...   0.000000
# purpose_business loan            0.000000   0.000000  ...   0.000000
# purpose_buy a car                0.000000   0.000000  ...   0.000000
# purpose_buy house                0.000000   0.000000  ...   0.000000
# purpose_debt consolidation       0.000000   1.000000  ...   1.000000
# purpose_educational expenses     0.000000   0.000000  ...   0.000000
# purpose_home improvements        0.000000   0.000000  ...   0.000000
# purpose_major purchase           1.000000   0.000000  ...   0.000000
# purpose_medical bills            0.000000   0.000000  ...   0.000000
# purpose_moving                   0.000000   0.000000  ...   0.000000
# purpose_other                    0.000000   0.000000  ...   0.000000
# purpose_small business           0.000000   0.000000  ...   0.000000
# purpose_take a trip              0.000000   0.000000  ...   0.000000
# purpose_vacation                 0.000000   0.000000  ...   0.000000
# purpose_wedding                  0.000000   0.000000  ...   0.000000
# term_Long Term                   0.000000   0.000000  ...   0.000000
# term_Short Term                  1.000000   1.000000  ...   1.000000
#
# Id                                   9991       9992       9993       9994  \
# annual_income                   13.727990  13.528496  14.527618  13.718823
# tax_liens                        0.000000   0.000000   0.000000   0.000000
# number_of_open_accounts          2.833213   1.791759   2.772589   2.708050
# years_of_credit_history          2.595255   1.987874   2.610070   2.493205
# maximum_open_credit             12.664709  12.001499  13.649457  12.991177
# number_of_credit_problems        0.000000   0.000000   0.000000   0.000000
# months_since_last_delinquent     4.304065   3.569533   3.496508   3.367296
# bankruptcies                     0.000000   0.000000   0.000000   0.000000
# current_loan_amount             12.999122  12.065666  12.976776  12.817975
# current_credit_balance          11.391006  11.610406  11.391006  11.387997
# monthly_debt                     7.746733   8.655563  10.210163   9.843684
# credit_score                     6.605298   6.538140   6.541030   6.559615
# home_ownership_Have Mortgage     0.000000   0.000000   0.000000   0.000000
# home_ownership_Home Mortgage     0.000000   1.000000   0.000000   1.000000
# home_ownership_Own Home          0.000000   0.000000   0.000000   0.000000
# home_ownership_Rent              1.000000   0.000000   1.000000   0.000000
# years_in_current_job_1 year      0.000000   0.000000   0.000000   1.000000
# years_in_current_job_10+ years   0.000000   0.000000   1.000000   0.000000
# years_in_current_job_2 years     1.000000   0.000000   0.000000   0.000000
# years_in_current_job_3 years     0.000000   1.000000   0.000000   0.000000
# years_in_current_job_4 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_5 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_6 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_7 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_8 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_9 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_< 1 year    0.000000   0.000000   0.000000   0.000000
# purpose_business loan            0.000000   0.000000   0.000000   0.000000
# purpose_buy a car                0.000000   0.000000   0.000000   0.000000
# purpose_buy house                0.000000   0.000000   0.000000   0.000000
# purpose_debt consolidation       0.000000   0.000000   1.000000   1.000000
# purpose_educational expenses     0.000000   0.000000   0.000000   0.000000
# purpose_home improvements        0.000000   0.000000   0.000000   0.000000
# purpose_major purchase           0.000000   0.000000   0.000000   0.000000
# purpose_medical bills            0.000000   0.000000   0.000000   0.000000
# purpose_moving                   0.000000   0.000000   0.000000   0.000000
# purpose_other                    1.000000   1.000000   0.000000   0.000000
# purpose_small business           0.000000   0.000000   0.000000   0.000000
# purpose_take a trip              0.000000   0.000000   0.000000   0.000000
# purpose_vacation                 0.000000   0.000000   0.000000   0.000000
# purpose_wedding                  0.000000   0.000000   0.000000   0.000000
# term_Long Term                   0.000000   0.000000   0.000000   1.000000
# term_Short Term                  1.000000   1.000000   1.000000   0.000000
#
# Id                                   9995       9996       9997       9998  \
# annual_income                   13.835366  14.087440  13.974058  13.491885
# tax_liens                        0.000000   0.000000   0.000000   0.000000
# number_of_open_accounts          2.708050   2.772589   3.891820   2.708050
# years_of_credit_history          3.404525   2.890372   2.624669   3.394508
# maximum_open_credit             13.234178  14.368120  14.349915  13.759766
# number_of_credit_problems        0.693147   0.000000   0.000000   0.000000
# months_since_last_delinquent     4.234107   4.356709   3.367296   3.496508
# bankruptcies                     0.693147   0.000000   0.000000   0.000000
# current_loan_amount             18.420681  13.057319  12.972696  12.459842
# current_credit_balance          11.999885  14.179647  13.424598  12.877099
# monthly_debt                     9.618934  10.404172  10.516319   9.510963
# credit_score                     6.614726   6.597146   6.545350   6.613384
# home_ownership_Have Mortgage     0.000000   0.000000   0.000000   0.000000
# home_ownership_Home Mortgage     1.000000   1.000000   1.000000   0.000000
# home_ownership_Own Home          0.000000   0.000000   0.000000   0.000000
# home_ownership_Rent              0.000000   0.000000   0.000000   1.000000
# years_in_current_job_1 year      0.000000   0.000000   0.000000   0.000000
# years_in_current_job_10+ years   1.000000   0.000000   0.000000   1.000000
# years_in_current_job_2 years     0.000000   1.000000   1.000000   0.000000
# years_in_current_job_3 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_4 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_5 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_6 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_7 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_8 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_9 years     0.000000   0.000000   0.000000   0.000000
# years_in_current_job_< 1 year    0.000000   0.000000   0.000000   0.000000
# purpose_business loan            0.000000   0.000000   0.000000   0.000000
# purpose_buy a car                0.000000   0.000000   0.000000   0.000000
# purpose_buy house                0.000000   0.000000   0.000000   0.000000
# purpose_debt consolidation       1.000000   1.000000   1.000000   1.000000
# purpose_educational expenses     0.000000   0.000000   0.000000   0.000000
# purpose_home improvements        0.000000   0.000000   0.000000   0.000000
# purpose_major purchase           0.000000   0.000000   0.000000   0.000000
# purpose_medical bills            0.000000   0.000000   0.000000   0.000000
# purpose_moving                   0.000000   0.000000   0.000000   0.000000
# purpose_other                    0.000000   0.000000   0.000000   0.000000
# purpose_small business           0.000000   0.000000   0.000000   0.000000
# purpose_take a trip              0.000000   0.000000   0.000000   0.000000
# purpose_vacation                 0.000000   0.000000   0.000000   0.000000
# purpose_wedding                  0.000000   0.000000   0.000000   0.000000
# term_Long Term                   0.000000   0.000000   0.000000   0.000000
# term_Short Term                  1.000000   1.000000   1.000000   1.000000
#
# Id                                   9999
# annual_income                   14.342863
# tax_liens                        0.000000
# number_of_open_accounts          2.564949
# years_of_credit_history          2.965273
# maximum_open_credit             13.997623
# number_of_credit_problems        0.693147
# months_since_last_delinquent     4.290459
# bankruptcies                     0.000000
# current_loan_amount             13.545020
# current_credit_balance          13.234856
# monthly_debt                    10.062242
# credit_score                     8.827761
# home_ownership_Have Mortgage     0.000000
# home_ownership_Home Mortgage     0.000000
# home_ownership_Own Home          0.000000
# home_ownership_Rent              1.000000
# years_in_current_job_1 year      0.000000
# years_in_current_job_10+ years   1.000000
# years_in_current_job_2 years     0.000000
# years_in_current_job_3 years     0.000000
# years_in_current_job_4 years     0.000000
# years_in_current_job_5 years     0.000000
# years_in_current_job_6 years     0.000000
# years_in_current_job_7 years     0.000000
# years_in_current_job_8 years     0.000000
# years_in_current_job_9 years     0.000000
# years_in_current_job_< 1 year    0.000000
# purpose_business loan            0.000000
# purpose_buy a car                0.000000
# purpose_buy house                0.000000
# purpose_debt consolidation       1.000000
# purpose_educational expenses     0.000000
# purpose_home improvements        0.000000
# purpose_major purchase           0.000000
# purpose_medical bills            0.000000
# purpose_moving                   0.000000
# purpose_other                    0.000000
# purpose_small business           0.000000
# purpose_take a trip              0.000000
# purpose_vacation                 0.000000
# purpose_wedding                  0.000000
# term_Long Term                   1.000000
# term_Short Term                  0.000000
#
# [43 rows x 2500 columns]

# %% [raw]
# prediction_dt = model_dt.predict(test_final)
# prediction_knn = model_knn.predict(test_final)
# prediction_nb = model_nb.predict(test_final)
# prediction_rf = model_rf.predict(test_final)
# prediction_svc = model_svc.predict(test_final)

# %% [raw]
# submission_result_dt = pd.DataFrame({'Id': test_final.index, 'Credit Default' : prediction_dt})
# submission_result_dt.to_csv('submission_result_dt.csv', index=False)
#
# submission_result_knn = pd.DataFrame({'Id': test_final.index, 'Credit Default' : prediction_knn})
# submission_result_knn.to_csv('submission_result_knn.csv', index=False)
#
# submission_result_nb = pd.DataFrame({'Id': test_final.index, 'Credit Default' : prediction_nb})
# submission_result_knn.to_csv('submission_result_nb.csv', index=False)
#
# submission_result_rf = pd.DataFrame({'Id': test_final.index, 'Credit Default' : prediction_rf})
# submission_result_knn.to_csv('submission_result_rf.csv', index=False)
#
# submission_result_svc = pd.DataFrame({'Id': test_final.index, 'Credit Default' : prediction_svc})
# submission_result_knn.to_csv('submission_result_svc.csv', index=False)
