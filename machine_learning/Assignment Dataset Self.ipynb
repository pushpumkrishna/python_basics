# %%
import pandas as pd
import numpy as np

df = pd.read_excel("E:/Data Science/Datasets/assignment_data.xlsx")

# %%
df.T
# Out:
#                                                               0     \
# Child name                                                CH_30001
# phone                                                 911100221000
# email_id                                s2m_test_20001@tests2m.com
# school                                            St.paul's school
# grade                                                      Grade 2
# batch_preferred  Afternoon Batch (4:00 - 4:45 PM), Evening Batc...
# source                                                  lastchance
# Submitted At                                   2020-04-16 08:46:39
#
#                                                               1     \
# Child name                                                CH_30002
# phone                                                 911100221001
# email_id                                s2m_test_20002@tests2m.com
# school                                         K L E School haveri
# ...

# %%
df.isna().sum()
# Out:
# Child name         0
# phone              0
# email_id           0
# school             0
# grade              0
# batch_preferred    0
# source             2
# Submitted At       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1683 entries, 0 to 1682
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Child name       1683 non-null   object
#  1   phone            1683 non-null   int64
#  2   email_id         1683 non-null   object
#  3   school           1683 non-null   object
#  4   grade            1683 non-null   object
#  5   batch_preferred  1683 non-null   object
#  6   source           1681 non-null   object
#  7   Submitted At     1683 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 105.3+ KB

# %%
df.nunique()
# Out:
# Child name         1439
# phone              1445
# email_id           1458
# school             1107
# grade                 4
# batch_preferred       8
# source               23
# Submitted At       1668
# dtype: int64
