# %%
import pandas as pd

submission = pd.read_csv("E:/Data Science/Datasets/Big Mart Sales/Submission.csv")
submission
# Out:
#       Unnamed: 0 Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              0           FDW58            OUT049        1636.244023
# 1              1           FDW14            OUT017        1409.355910
# 2              2           NCN55            OUT010         710.594286
# 3              3           FDQ58            OUT017        2355.184955
# 4              4           FDY38            OUT027        5857.916205
# ...          ...             ...               ...                ...
# 5676        5676           FDB58            OUT046        2125.984810
# 5677        5677           FDD47            OUT018        2602.671833
# 5678        5678           NCO17            OUT045        1832.451358
# 5679        5679           FDJ26            OUT017        3538.685188
# 5680        5680           FDU37            OUT045        1281.144462
#
# [5681 rows x 4 columns]

# %%
# getting the stats of the dataset using decribe function

submission.describe()
# Out:
#         Unnamed: 0  Item_Outlet_Sales
# count  5681.000000        5681.000000
# mean   2840.000000        2177.673697
# std    1640.107771        1291.691929
# min       0.000000        -100.129007
# 25%    1420.000000        1083.959472
# 50%    2840.000000        1953.891192
# 75%    4260.000000        3171.909850
# max    5680.000000        5959.724713

# %%
# getting the info about the dataset

submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5681 non-null   int64
#  1   Item_Identifier    5681 non-null   object
#  2   Outlet_Identifier  5681 non-null   object
#  3   Item_Outlet_Sales  5681 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 177.7+ KB

# %%
# Defining a function to calculate the total NaN values in the dataset/column

def nan_values(x):
    """
    Function to print all NaN values present in the dataset/column
    """
    
    val = x.isnull().sum()
    return val

# %% [raw]
# # Calling the function and gettin count of all NaN values
#
# print('Total NaN values present are :: \n')
# train.apply(nan_values, axis = 0)                 # Setting axis =0 to iterate over columns

# %%
# Importing training dataset

train = pd.read_csv("E:/Data Science/Datasets/Big Mart Sales/Train.csv")
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# Importing the test dataset

test = pd.read_csv("E:/Data Science/Datasets/Big Mart Sales/Test.csv")
test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
# Importing libraries to make the model

#for modelling
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# * Using two features, MRP and the store establishment year to estimate sales. Now, let us built a linear regression model in python considering only these two features.

# %%
# Defining the predictor variable

X = train[['Item_MRP', 'Outlet_Establishment_Year']]

# Defining our target variable

Y = train['Item_Outlet_Sales']

# %%
# dividing the data into training and validation data

x_train, x_val, y_train, y_val = train_test_split(X, Y, test_size = 0.2)

x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((6818, 2), (1705, 2), (6818,), (1705,))

# %%
# defining our model

model = LinearRegression()

# Fitting the data into the model and training the algorithm

model.fit(x_train, y_train)

# making the predictions on the validation data

y_predict = model.predict(x_val)

print('Predicted Values of the model are:: \n', y_predict)
# Out:
# Predicted Values of the model are::
#  [3503.04578612  912.11830204 2814.05347596 ... 1156.21934872 3880.88003684
#  1502.73329306]

# %%
# Defining a function to calculate the Mean Squared Error

import numpy as np

def mse(x,y):
    """
    Function to return the calculated Mean Squared error of the model
    """
    
    error = round(np.mean((x-y)**2), 4)
    return error

# %%
# Calling the mse function to calculate the MSE of the model

print("Mean Squared error of the model is:: ", mse(y_predict, y_val))
# Out:
# Mean Squared error of the model is::  1901951.7151

# %%
# Calculating the coeficients of our equation

coeff = model.coef_

# Substituting the values in the dataframe

col = x_train.columns      # Defining the columns

coef_df = pd.DataFrame({'Input Variables' : col, 'Calculated Coefficients': coeff})
coef_df
# Out:
#              Input Variables  Calculated Coefficients
# 0                   Item_MRP                15.492833
# 1  Outlet_Establishment_Year               -10.481522

# %% [markdown]
# # Observation::
#
#   * We can see that MRP has a high coefficient, meaning items having higher prices have better sales.

# %% [markdown]
# # R-Square:
#
#  * It determines how much of the total variation in Y (dependent variable) is explained by the variation in X (independent variable).
#  * The value of R-square is always between 0 and 1, where 0 means that the model does not model explain any variability in the target variable (Y) and 1 meaning it explains full variability in the target variable.

# %%
# Calculating the R square value

r_square = round(model.score(x_val, y_val), 4)
print('R-Square value of the model is:: ', r_square)
# Out:
# R-Square value of the model is::  0.3378

# %% [markdown]
# * R² is 29%, meaning, only 29% of variance in sales is explained by year of establishment and MRP.
# * In other words, if you know year of establishment and the MRP, you’ll have 29% information to make an accurate prediction about its sales.
#
# ------------------------------------------------------------------------------------------------------------
#
# * Increasing one more predictor variable to see if the value of R² increases or decreases

# %%
# Calling NaN missing function and checking to total NaN values present

temp1 = train[['Item_Weight']]
print('Total number of NaN values present in Item Weight column is:: ')
temp1.apply(nan_values)
# Out:
# Total number of NaN values present in Item Weight column is::
# Item_Weight    1463
# dtype: int64

# %%
# Filling the missing values with the mean value of the weight column

weight_mean = round(np.mean(train['Item_Weight']), 4)
print('Average weight of the item weights is :: ', weight_mean)

# Substituting the mean values in the item weight column

train['Item_Weight'].fillna(weight_mean, inplace = True)
# Out:
# Average weight of the item weights is ::  12.8576

# %%
# Checking again to see if there are any missing values in the dataset

temp2 = train[['Item_Weight']]
print('Total number of NaN values present in Item Weight column is:: ')
temp2.apply(nan_values)
# Out:
# Total number of NaN values present in Item Weight column is::
# Item_Weight    0
# dtype: int64

# %%
# Defining new predictor variable and using weight coloumn as  third predictor

features = ['Item_MRP','Outlet_Establishment_Year', 'Item_Weight']
X_second = train[features]

# keeping the target variable same

# %%
# dividing the data into training and validation data

x_train_1, x_val_1, y_train_1, y_val_1 = train_test_split(X_second, Y, test_size = 0.2)

x_train_1.shape, x_val_1.shape, y_train_1.shape, y_val_1.shape
# Out:
# ((6818, 3), (1705, 3), (6818,), (1705,))

# %%
# Defininig our new model

model_new = LinearRegression()

# Fitting the data into model and training it

model_new.fit(x_train_1, y_train_1)

# Predicting sales values based on new model

y_predict_1 = model_new.predict(x_val_1)

# Printing the predicted values and the shape of the array

print('Predicted Values of the sales are:: ',y_predict_1)
print('Shape of the array is:: ', y_predict_1.shape)
# Out:
# Predicted Values of the sales are::  [2272.4991561  2640.61572817 2019.51516568 ... 1910.00029083 1341.16768232
#  2068.21514984]
# Shape of the array is::  (1705,)

# %%
# Calling mse function and getting the MSE for the new predictions

print('Mean Squared Error for the new model is:: ', mse(y_predict_1, y_val_1))
# Out:
# Mean Squared Error for the new model is::  1941470.3456

# %% [markdown]
# * Since the MSE Error has increased so we can either reject the newly added column or add another one as predictor variable
# * Adding Item_Visibility also as predictor variable to see it effects the sales or not

# %%
# Defining our predictor varaible again with new column added

features2 = ['Item_MRP','Outlet_Establishment_Year', 'Item_Weight', 'Item_Visibility'] 
X_third = train[features2]

print('Shape of our new predictor variable is :: ', X_third.shape)
# Out:
# Shape of our new predictor variable is ::  (8523, 4)

# %%
# Checking if the new column has any Missing/NaN values present and calling the nan function

temp3 = train[['Item_Visibility']]
temp3.apply(nan_values)
# Out:
# Item_Visibility    0
# dtype: int64

# %% [markdown]
# * Since it has no NaN values present hence we can proceed to split our data into training and validation data

# %%
x_train_2, x_val_2, y_train_2, y_val_2 = train_test_split(X_third, Y, test_size = 0.2)

x_train_2.shape, x_val_2.shape, y_train_2.shape, y_val_2.shape
# Out:
# ((6818, 4), (1705, 4), (6818,), (1705,))

# %%
# Making new Linear model

model_2 = LinearRegression()

# Fitting the data and training our model

model_2.fit(x_train_2, y_train_2)

# Predicting the sales values based on our new model

y_predict_2 = model_2.predict(x_val_2)

print('The new predicted values are ::', y_predict_2)
print('\n Shape of array is :: ', y_predict_2.shape)
# Out:
# The new predicted values are :: [ 856.21848974 3249.17369333 1331.2877784  ... 3056.29826576 2461.10411976
#  3973.78896041]
#
#  Shape of array is ::  (1705,)

# %%
# Calling the MSE function and calculating MSe of new model

print('Mean squared error of our new model is :: ', mse(y_predict_2, y_val_2))
# Out:
# Mean squared error of our new model is ::  1784812.5603

# %% [markdown]
# * Since value of MSE again increased it shows our new model is not as good as our old models

# %%
train.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.012049  0.024756
# Item_Visibility              -0.012049         1.000000 -0.001315
# Item_MRP                      0.024756        -0.001315  1.000000
# Outlet_Establishment_Year    -0.008298        -0.074834  0.005020
# Item_Outlet_Sales             0.011550        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.008298           0.011550
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
r_square_new = model_2.score(x_val_2, y_val_2)
r_square_new
# Out:
# 0.3485845485408958

# %%
# calculating coefficients of the linear equation

coef_2 = model_2.coef_
col2 = X_third.columns

#Creating a datarame and substituting above values

coef_df = pd.DataFrame({'Columns/Predictors': col2, 'Coefficiants': coef_2})
coef_df
# Out:
#           Columns/Predictors  Coefficiants
# 0                   Item_MRP     15.640210
# 1  Outlet_Establishment_Year    -11.622857
# 2                Item_Weight     -0.900422
# 3            Item_Visibility  -4235.981743

# %%
temp5 = train[['Outlet_Size']]
temp5.apply(nan_values)
# Out:
# Outlet_Size    2410
# dtype: int64

# %%
train['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
# Substituting missing values in Outlet size with 'Small' as its count is higher

train['Outlet_Size'].fillna('Small', inplace = True)

# %% [markdown]
# # Categorial variable change :
#
#     * Using get_dummy function to change the categorial variable into numeric values

# %%
# creating dummy variables to convert categorical into numeric values 

mylist = list(train.select_dtypes(include=['object']).columns) 
mylist
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
dummies = pd.get_dummies(train[mylist], prefix= mylist) 
dummies
# Out:
#       Item_Identifier_DRA12  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# 0                         0                      0                      0
# 1                         0                      0                      0
# 2                         0                      0                      0
# 3                         0                      0                      0
# 4                         0                      0                      0
# ...                     ...                    ...                    ...
# 8518                      0                      0                      0
# 8519                      0                      0                      0
# 8520                      0                      0                      0
# 8521                      0                      0                      0
# 8522                      0                      0                      0
#
#       Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  \
# ...

# %%
train.drop(mylist, axis=1, inplace = True)  
D = pd.concat([train,dummies], axis =1 )
D
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales  Item_Identifier_DRA12  Item_Identifier_DRA24  \
# ...
