# %%
import numpy as np
np.set_printoptions(precision = 4)       ## Print array to 4 decimal places
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Ccalculating and plotting t statistics value with dof 20

# %%
values = np.linspace(-4,4,50)
print('Random values for test is ::', values)
# Out:
# Random values for test is :: [-4.     -3.8367 -3.6735 -3.5102 -3.3469 -3.1837 -3.0204 -2.8571 -2.6939
#  -2.5306 -2.3673 -2.2041 -2.0408 -1.8776 -1.7143 -1.551  -1.3878 -1.2245
#  -1.0612 -0.898  -0.7347 -0.5714 -0.4082 -0.2449 -0.0816  0.0816  0.2449
#   0.4082  0.5714  0.7347  0.898   1.0612  1.2245  1.3878  1.551   1.7143
#   1.8776  2.0408  2.2041  2.3673  2.5306  2.6939  2.8571  3.0204  3.1837
#   3.3469  3.5102  3.6735  3.8367  4.    ]

# %%
# making a t-distribution object with dof 20

import scipy.stats

t_distribution = scipy.stats.t(20)
print(f't statistic value for dof 20:: {t_distribution}')

# Calculating the Probability distribution function

t_pdf = t_distribution.pdf(values)
print('\n',t_pdf)
# Out:
# t statistic value for dof 20:: <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000016EA6ACA308>
#
#  [0.0008 0.0012 0.0018 0.0026 0.0037 0.0053 0.0076 0.0108 0.0153 0.0213
#  0.0294 0.0402 0.0541 0.0716 0.0934 0.1195 0.1501 0.1844 0.2217 0.2602
#  0.2979 0.3324 0.3611 0.3818 0.3926 0.3926 0.3818 0.3611 0.3324 0.2979
#  0.2602 0.2217 0.1844 0.1501 0.1195 0.0934 0.0716 0.0541 0.0402 0.0294
#  0.0213 0.0153 0.0108 0.0076 0.0053 0.0037 0.0026 0.0018 0.0012 0.0008]

# %%
# plotting t statistics value with dof 20

ax = plt.plot(values, t_pdf)

plt.xlabel('Random Values')
plt.ylabel('Probability Density Function')
plt.title('PDF for t distribution with df=20')
# Out:
# Text(0.5, 1.0, 'PDF for t distribution with df=20')

# %% [markdown]
# The t distribution object 't_distribution' can also give us the cumulative distribution function(CDF). The CDF gives the area under the curve of the PDF at and to the left of the given t-value:

# %%
## Calculating the CDF value

t_cdf = t_distribution.cdf(values) 
t_cdf
# Out:
# array([3.5176e-04, 5.1515e-04, 7.5376e-04, 1.1012e-03, 1.6054e-03,
#        2.3334e-03, 3.3790e-03, 4.8706e-03, 6.9819e-03, 9.9437e-03,
#        1.4056e-02, 1.9700e-02, 2.7345e-02, 3.7553e-02, 5.0966e-02,
#        6.8289e-02, 9.0240e-02, 1.1750e-01, 1.5062e-01, 1.8995e-01,
#        2.3553e-01, 2.8704e-01, 3.4375e-01, 4.0452e-01, 4.6788e-01,
#        5.3212e-01, 5.9548e-01, 6.5625e-01, 7.1296e-01, 7.6447e-01,
#        8.1005e-01, 8.4938e-01, 8.8250e-01, 9.0976e-01, 9.3171e-01,
#        9.4903e-01, 9.6245e-01, 9.7266e-01, 9.8030e-01, 9.8594e-01,
#        9.9006e-01, 9.9302e-01, 9.9513e-01, 9.9662e-01, 9.9767e-01,
#        9.9839e-01, 9.9890e-01, 9.9925e-01, 9.9948e-01, 9.9965e-01])

# %%
# Plotting the CDF 

plt.plot(values, t_cdf)
plt.xlabel('Random Values')
plt.ylabel('Cumulative Distribution Function')
plt.title('CDF for t distribution with df=20')
# Out:
# Text(0.5, 1.0, 'CDF for t distribution with df=20')

# %%
# for data manipulation

import numpy as np
import pandas as pd

# for visualization

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# for Machine learning
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# for warnings

import warnings
warnings.filterwarnings('ignore')

# %%
np.random.seed(123)

#The numpy.random.seed() makes the random numbers predictable and is used for reproducibility

# %%
# Importing the dataset

data =pd.read_csv("E:/Data Science/CSV dataset/data.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
## Removing the Id and the Unnamed columns

data = data.iloc[:,1:-1]
data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
## Encoding the values

label_encoder = LabelEncoder()
data.iloc[:,0] = label_encoder.fit_transform(data.iloc[:,0]).astype('float64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    float64
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
## Generating the correlation matrix

corr = data.corr()
corr
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                 1.000000     0.730029      0.415185        0.742636
# radius_mean               0.730029     1.000000      0.323782        0.997855
# texture_mean              0.415185     0.323782      1.000000        0.329533
# perimeter_mean            0.742636     0.997855      0.329533        1.000000
# area_mean                 0.708984     0.987357      0.321086        0.986507
# smoothness_mean           0.358560     0.170581     -0.023389        0.207278
# compactness_mean          0.596534     0.506124      0.236702        0.556936
# concavity_mean            0.696360     0.676764      0.302418        0.716136
# concave points_mean       0.776614     0.822529      0.293464        0.850977
# symmetry_mean             0.330499     0.147741      0.071401        0.183027
# fractal_dimension_mean   -0.012838    -0.311631     -0.076437       -0.261477
# ...

# %%
## Plotting the heatmap to visualize the correlation

sns.heatmap(corr)

# %%
columns = np.full((corr.shape[0],),True, dtype = bool)
columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
# Removing the diagnosis column because it is the column which we are trying to predict

selected_columns = data.iloc[:,1:]
selected_columns
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# NEW PROBLEM ::

# %% [markdown]
# The test will tell us whether means of the sample and the population are different. Consider the voting populace in India and in Gujarat. Does the average age of Gujarati voters differ from that of the population.

# %%
# For data manipulation
import pandas as pd
import numpy as np

# for statistics
import scipy.stats as stats
import math

# for data visualization
import matplotlib.pyplot as plt

# %%
## Generating the input data and using stats function

from scipy.stats import poisson
np.random.seed(10)

population_ages1 = stats.poisson.rvs(loc = 18, mu = 30, size = 150000)
population_ages1
# Out:
# array([53, 50, 48, ..., 47, 47, 52])

# %%
population_ages2 = stats.poisson.rvs(loc = 18, mu = 20, size = 100000)
population_ages2
# Out:
# array([40, 34, 36, ..., 38, 35, 43])

# %%
# Combining both the arrays 

population_ages = np.concatenate((population_ages1, population_ages2))
population_ages
# Out:
# array([53, 50, 48, ..., 38, 35, 43])

# %%
## Generating Gujarat population

gujarat_pop1 = stats.poisson.rvs(loc = 18, mu = 22, size = 30)
gujarat_pop2 = stats.poisson.rvs(loc = 18, mu = 25, size = 20)

#Concatenating both arrays into one

gujarat_pop = np.concatenate((gujarat_pop1, gujarat_pop2))
gujarat_pop
# Out:
# array([45, 39, 41, 41, 50, 41, 46, 42, 40, 39, 46, 36, 43, 42, 43, 43, 52,
#        39, 41, 38, 37, 38, 36, 34, 42, 38, 43, 40, 38, 32, 37, 42, 46, 39,
#        41, 39, 39, 44, 45, 46, 42, 45, 46, 35, 40, 42, 44, 47, 40, 39])

# %%
# Calculating mean of both population ages

mean_val_population = population_ages.mean()
print("Mean value of the Population is:: ", mean_val_population)

mean_val_gujarat = gujarat_pop.mean()
print("\nMean value of the Gujarat Population is:: ", mean_val_gujarat)
# Out:
# Mean value of the Population is::  44.001608
#
# Mean value of the Gujarat Population is::  41.26

# %%
# performing the t test 

stats.ttest_1samp(a = gujarat_pop, popmean = mean_val_population)
# Out:
# Ttest_1sampResult(statistic=-4.910771804265661, pvalue=1.0498595271892073e-05)

# %% [markdown]
# Performing the Two Samplt t-test

# %%
# Generating the second sample of Delhi ages population

delhi_ages1 = stats.poisson.rvs(loc = 18, mu = 30, size = 100000)
delhi_ages2 = stats.poisson.rvs(loc = 18, mu = 20, size = 150000)

#Concatenating both ages into one

delhi_ages = np.concatenate((delhi_ages1, delhi_ages2))
print("Delhi population's ages: ", delhi_ages)

mean_val_delhi = delhi_ages.mean()
print('Mean of Delhi population of ages array:', mean_val_delhi)
# Out:
# Delhi population's ages:  [44 44 44 ... 41 36 38]
# Mean of Delhi population of ages array: 41.994676

# %%
## Performing the two sample t test to see the variation in the ages mean

stats.ttest_ind(a = gujarat_pop, b = delhi_ages, equal_var = False)
# Out:
# Ttest_indResult(statistic=-1.3155462780156577, pvalue=0.19444132277444837)

# %% [markdown]
# The value of 1.908 tells us there’s a 19.44% chance that the sample data is such far apart for two identical groups. This is greater than the 5% confidence level.

# %% [markdown]
# When you want to check how different samples from the same group are, you can go for a paired T-test. Let’s take an example.

# %%
np.random.seed(11)

from scipy.stats import norm 

before = stats.norm.rvs(scale = 30, loc = 250, size = 100)
after = before + stats.norm.rvs(scale = 5, loc = -1.25, size = 100)

## creating the dataframe of two values

dataframe = pd.DataFrame({"weight_before": before,
                         "weights_after": after,
                         "weights_change": after-before})
dataframe
# Out:
#     weight_before  weights_after  weights_change
# 0      302.483642     305.605006        3.121364
# 1      241.417810     240.526071       -0.891739
# 2      235.463046     226.017788       -9.445258
# 3      170.400443     165.913930       -4.486513
# 4      249.751461     252.590309        2.838848
# ..            ...            ...             ...
# 95     258.148189     256.671813       -1.476376
# 96     275.760015     272.554150       -3.205866
# 97     212.077790     218.498901        6.421112
# 98     283.446109     281.375144       -2.070965
# 99     263.043310     263.595143        0.551833
#
# [100 rows x 3 columns]

# %%
dataframe.describe()
# Out:
#        weight_before  weights_after  weights_change
# count     100.000000     100.000000      100.000000
# mean      250.345546     249.115171       -1.230375
# std        28.132539      28.422183        4.783696
# min       170.400443     165.913930      -11.495286
# 25%       230.421042     229.148236       -4.046211
# 50%       250.830805     251.134089       -1.413463
# 75%       270.637145     268.927258        1.738673
# max       314.700233     316.720357        9.759282

# %%
stats.ttest_rel(a= before, b = after)
# Out:
# Ttest_relResult(statistic=2.5720175998568284, pvalue=0.011596444318439857)

# %% [markdown]
# So, we see we have just 1% chances to find such huge differences between samples.

# %% [markdown]
# Example of Correlation In Python

# %%
data = pd.read_csv("E:/Data Science/CSV dataset/data.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# Calculating the correlation between two columns

data[['radius_mean','texture_mean']].corr()
# Out:
#               radius_mean  texture_mean
# radius_mean      1.000000      0.323782
# texture_mean     0.323782      1.000000

# %%
# Calculating the covariance between two columns

data[['radius_mean','texture_mean']].cov()
# Out:
#               radius_mean  texture_mean
# radius_mean     12.418920      4.907582
# texture_mean     4.907582     18.498909

# %%
## Plotting the correlation plot

import seaborn as sns

columns = data[['radius_mean','texture_mean']]
sns.pairplot(columns, kind = 'scatter')

# %% [markdown]
# What is t-test?
#
# The t test (also called Student’s T Test) compares two averages (means) and tells you if they are different from each other. The t test also tells you how significant the differences are; In other words it lets you know if those differences could have happened by chance.

# %% [markdown]
# What is t-score?
#
# The t score is a ratio between the difference between two groups and the difference within the groups. The larger the t score, the more difference there is between groups. The smaller the t score, the more similarity there is between groups. A t score of 3 means that the groups are three times as different from each other as they are within each other. When you run a t test, the bigger the t-value, the more likely it is that the results are repeatable.
#
#     A large t-score tells you that the groups are different.
#     A small t-score tells you that the groups are similar.

# %% [markdown]
# What are T-Values and P-values?
#
# How big is “big enough”? Every t-value has a p-value to go with it. A p-value is the probability that the results from your sample data occurred by chance. P-values are from 0% to 100%. They are usually written as a decimal. For example, a p value of 5% is 0.05. Low p-values are good; They indicate your data did not occur by chance. For example, a p-value of .01 means there is only a 1% probability that the results from an experiment happened by chance. In most cases, a p-value of 0.05 (5%) is accepted to mean the data is valid.

# %%
import numpy as np

data1 = data['radius_mean']
data2 = data['texture_mean']

mean1, mean2 = np.mean(data1), np.mean(data2)
print('Mean of Radius Mean column:', mean1)
print('\nMean of Texture Mean column:', mean2)
# Out:
# Mean of Radius Mean column: 14.127291739894563
#
# Mean of Texture Mean column: 19.28964850615117

# %%
# Calculating standard deviation of both columns

std1, std2 = np.std(data1, ddof = 1), np.std(data2, ddof =1)


print('Standard Deviation of Radius Mean column:', std1)
print('\nStandard Deviation of Texture Mean column:', std2)
# Out:
# Standard Deviation of Radius Mean column: 3.524048826212078
#
# Standard Deviation of Texture Mean column: 4.301035768166949

# %%
## Calculating the Standard Error Deviation 

import math

n1, n2 = len(data1), len(data2)
sed1, sed2 = std1/math.sqrt(n1), std2/math.sqrt(n2)

print('Standard Error Deviation of Radius Mean column:', sed1)
print('\nStandard Error Deviation of Texture Mean column:', sed1)
# Out:
# Standard Error Deviation of Radius Mean column: 0.1477358120934635
#
# Standard Error Deviation of Texture Mean column: 0.1477358120934635

# %%
# Standard error deviation of both 

sed = math.sqrt(sed1**2 + sed2**2)
print('Standard Error Deviation of Both columns:', sed)
# Out:
# Standard Error Deviation of Both columns: 0.23310326731138845

# %%
## t statistic value 

t_stat = (mean1 - mean2) / sed
print('t statistic value is:: ', t_stat)
# Out:
# t statistic value is::  -22.146222255051146

# %%
# Degree of freedom 

dof = n1 + n2 -2
print('Degree of freedom is:: ', dof)
# Out:
# Degree of freedom is::  1136

# %%
# Calculating  the critical  value

alpha = 0.05
critical_value = stats.t.ppf(1.0 - alpha, dof)
print('Critical value is:: ', critical_value)
# Out:
# Critical value is::  1.6461960742122779

# %%
## Calculating the p-value

p_value = (1 - stats.t.cdf(abs(t_stat), dof) * 2)
print('p value is ::', p_value)
# Out:
# p value is :: -1.0

# %%
## Now using the inbuilt function to calculate the t statistic and p value

# creating the random numbers

dat1 = 5*np.random.rand(50) + 50
dat2 = 5*np.random.rand(50) + 51

dat1, dat2
# Out:
# (array([52.9661, 52.9372, 52.2038, 51.2518, 51.6524, 53.2146, 51.4201,
#         51.731 , 51.7705, 51.624 , 54.1427, 52.7289, 50.0918, 53.7079,
#         52.5108, 53.8945, 52.4728, 51.5542, 54.1964, 50.8667, 51.3914,
#         52.4207, 54.2994, 50.5761, 51.6934, 52.6612, 53.3917, 50.526 ,
#         53.7764, 52.7846, 52.5857, 51.9044, 51.5732, 54.4525, 54.9689,
#         50.8761, 51.0575, 53.3352, 53.8228, 54.1148, 51.5122, 51.0455,
#         50.3628, 51.8817, 52.8124, 54.3628, 50.1652, 50.4483, 53.2657,
#         53.3566]),
#  array([51.6207, 51.4818, 51.1399, 54.2437, 52.3993, 52.205 , 54.3227,
#         51.605 , 53.6821, 51.4546, 51.3287, 54.3427, 54.9581, 53.3121,
#         53.0107, 54.5077, 51.3802, 52.3914, 55.5263, 55.7448, 51.192 ,
#         51.0153, 54.8394, 53.2594, 54.8122, 54.2149, 53.2398, 54.5499,
#         54.0226, 51.0786, 53.3306, 55.41  , 54.9014, 54.2746, 54.1079,
#         55.0831, 52.4567, 52.9705, 54.1533, 55.1048, 52.6069, 51.8424,
# ...

# %%
from scipy import stats
stats, p_val = stats.ttest_ind(dat1, dat2)
print('T Statistic value is : %.3f \nP-value is: %.3f' %(stats, p_val))
# Out:
# T Statistic value is : -3.559
# P-value is: 0.001

# %%
# Calculating the crtitcal value

from scipy import stats

n1 = len(dat1)
n2 = len(dat2)
dof1 = n1 + n2 - 2
print('Degree of freedom:: ', dof1)

alpha = 0.05
cv = stats.t.ppf(1.0 - alpha, dof1)
print('Critical Value is: ', cv)
# Out:
# Degree of freedom::  98
# Critical Value is:  1.6605512170440568

# %%
# t-test for independent samples

from math import sqrt
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from scipy.stats import sem
from scipy.stats import t
 
# function for calculating the t-test for two independent samples

def independent_ttest(data1, data2, alpha):
	
    # calculate means
	mean1, mean2 = mean(data1), mean(data2)
	
    # calculate standard errors
	se1, se2 = sem(data1), sem(data2)
	
    # standard error on the difference between the samples
	sed = sqrt(se1**2.0 + se2**2.0)
	
    # calculate the t statistic
	t_stat = (mean1 - mean2) / sed
	
    # degrees of freedom
	df = len(data1) + len(data2) - 2
	
    # calculate the critical value
	cv = t.ppf(1.0 - alpha, df)
	
    # calculate the p-value
	p = (1.0 - t.cdf(abs(t_stat), df)) * 2.0
	
    # return everything
	return t_stat, df, cv, p
 
# seed the random number generator
seed(1)

# generate two independent samples
data1 = 5 * randn(100) + 50
data2 = 5 * randn(100) + 51

# calculate the t test
alpha = 0.05
t_stat, df, cv, p = independent_ttest(data1, data2, alpha)
print('t=%.3f, df=%d, cv=%.3f, p=%.3f' % (t_stat, df, cv, p))

# interpret via critical value
if abs(t_stat) <= cv:
	print('Accept null hypothesis that the means are equal.')
else:
	print('Reject the null hypothesis that the means are equal.')
# interpret via p-value
if p > alpha:
	print('Accept null hypothesis that the means are equal.')
else:
	print('Reject the null hypothesis that the means are equal.')
# Out:
# t=-2.262, df=198, cv=1.653, p=0.025
# Reject the null hypothesis that the means are equal.
# Reject the null hypothesis that the means are equal.

# %%
import numpy as np

val1 = 5 * np.random.rand(50) + 10
val2 = 5 * np.random.rand(50) + 15
val1, val2

# %% [markdown]
# A simple way to calculate a confidence interval for a classification algorithm is to calculate the binomial proportion confidence interval, which can provide an interval around a model’s estimated accuracy or error.
#
# This can be implemented in Python using the confint() Statsmodels function.
#
# The function takes the count of successes (or failures), the total number of trials, and the significance level as arguments and returns the lower and upper bound of the confidence interval.
#
# The example below demonstrates this function in a hypothetical case where a model made 88 correct predictions out of a dataset with 100 instances and we are interested in the 95% confidence interval (provided to the function as a significance of 0.05).

# %%
from statsmodels.stats.proportion import proportion_confint

lower, upper = proportion_confint(80,100, 0.05)
lower, upper
# Out:
# (0.7216014406183978, 0.8783985593816023)

# %%
y = str(2.0)           # Specifying dtype changes it dtype in output
print(type(y))
# Out:
# <class 'str'>

# %%
bool(0)
bool(None)
bool('') # empty string
bool([]) # empty list
bool({}) # empty dictionary
# Out:
# False

# %%
##  create a list (two ways)

list1 = [1,2,3,4]
x = (5,6,7,8)

list2 = list(x)

print(list1)
print(list2)
# Out:
# [1, 2, 3, 4]
# [5, 6, 7, 8]

# %%
# modify a list (does not return the list)

simpsons = ['homer', 'marge', 'bart']

simpsons.append('lisa')                 # append element to end
print('\n',simpsons)

simpsons.extend(['itchy', 'scratchy'])  # append multiple elements to end
print('\n',simpsons)

simpsons.insert(0, 'maggie')            # insert element at index 0 (shifts everything␣˓→right)
print('\n',simpsons)

simpsons.remove('bart')                 # searches for first instance and removes it
print('\n',simpsons)

simpsons.pop(0)                         # removes element 0 and returns it
del simpsons[0]                         # removes element 0 (does not return it)

simpsons[0] = 'krusty'                  # replace element 0
print('\n',simpsons)
# Out:
#  ['homer', 'marge', 'bart', 'lisa']
#
#  ['homer', 'marge', 'bart', 'lisa', 'itchy', 'scratchy']
#
#  ['maggie', 'homer', 'marge', 'bart', 'lisa', 'itchy', 'scratchy']
#
#  ['maggie', 'homer', 'marge', 'lisa', 'itchy', 'scratchy']
#
#  ['krusty', 'lisa', 'itchy', 'scratchy']

# %%
# concatenate lists (slower than 'extend' method)

neighbors = simpsons + ['ned','rod','todd']
neighbors
# Out:
# ['krusty', 'lisa', 'itchy', 'scratchy', 'ned', 'rod', 'todd']

# %%
print(simpsons.count('lisa'))
print(neighbors.index('ned'))
# Out:
# 1
# 4

# %%
## returning the list reversed

list(reversed(neighbors))
# Out:
# ['todd', 'rod', 'ned', 'scratchy', 'itchy', 'lisa', 'krusty']

# %%
## Sort () function Sorts a list but not return it

ages = (32,12,6,55,43,66,90)
simpsons_age = list(ages)
simpsons_age.sort()
simpsons_age
# Out:
# [6, 12, 32, 43, 55, 66, 90]

# %%
simpsons_age.sort(reverse = True)
simpsons_age
# Out:
# [90, 66, 55, 43, 32, 12, 6]

# %%
simpsons_age.sort(key = len)
simpsons_age
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-261-4d2e4fc6409e> in <module>
# ----> 1 simpsons_age.sort(key = len)
#       2 simpsons_age
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# One sample 𝑡-test::
#
# The one-sample 𝑡-test is used to determine whether a sample comes from a population with a specific mean. For example you want to test if the average height of a population is 1.75 𝑚.
#
# 1). Model the data: Assume that height is normally distributed: 𝑋 ∼ 𝒩(𝜇, 𝜎), ie:
#
#                          height𝑖 = average height over the population + error𝑖 (4.6)
#
#                          𝑥𝑖 = 𝑥 + 𝜀𝑖           (The 𝜀𝑖 are called the residuals)
#
# 2). Fit: estimate the model parameters.. 𝑥, 𝑠𝑥 are the estimators of 𝜇, 𝜎.
#
# 3 Compute a test statistic:: In testing the null hypothesis that the population mean is equal to a specified value 𝜇0 = 1.75,
# one uses the statistic:
#                            𝑡 = (difference of means / std-dev of noise) * √𝑛
#                            𝑡 = effect size * √𝑛
#                            𝑡 = ((𝑥 − 𝜇0) / 𝑠𝑥) * √𝑛
#
# Remarks: Although the parent population does not need to be normally distributed, the distribution of the population of sample means, 𝑥, is assumed to be normal.
#
# Example:: Given the following samples, we will test whether its true mean is 1.75.

# %%
import  numpy as np

x = [1.83, 1.83, 1.73, 1.82, 1.83, 1.73, 1.99, 1.85, 1.68, 1.87]

# Calculating the parameters now

mu = 1.75
x_bar = np.mean(x)                     ## Calculating mean of the samples
x_std = np.std(x, ddof = 1)             ## Calculating standard deviation of the samples
n = len(x)                              ## Calculating length of the samples

def t_statistic(xbar, mu, s, n):
    """
    Function to calculate t statistic value 
    """
    
    t_stat = (xbar - mu) / (s / np.sqrt(n))
    print(f' t-statistic value of the sample is:: ', t_stat)
    
    
t_statistic(x_bar, mu, x_std, n)
# Out:
#  t-statistic value of the sample is::  2.3968766311585883

# %%
## Computing covariance and p value using the pearson test

import numpy as np
from scipy.stats import stats

# generating the samples

n = 50
x = np.random.normal(size = n)                   ## Cannot write normal(50). it is giving error
y = 2 * x + np.random.normal(size = n)           ## Cannot write normal(50). it is giving error

cov, pval = stats.pearsonr(x,y)
print('Covariance is: {} \np- Value is:: {}'.format(cov,pval))
# Out:
# Covariance is: 0.8428698452652972
# p- Value is:: 1.629011048151783e-14
