# %%
#Importing panda library to read the cvs file and load the dataset

import pandas as pd

#Saving the dataset in data variable

data = pd.read_csv("E:/Data Science/CSV dataset/USA_cars_datasets.csv")
data
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %%
#Printing the NaN values present 

data.isnull().sum()
# Out:
# Unnamed: 0      0
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           0
# vin             0
# lot             0
# state           0
# country         0
# condition       0
# dtype: int64

# %%
#Printing the column list of the dataset

data.columns
# Out:
# Index(['Unnamed: 0', 'price', 'brand', 'model', 'year', 'title_status',
#        'mileage', 'color', 'vin', 'lot', 'state', 'country', 'condition'],
#       dtype='object')

# %%
# Selecting the predictor variable

features = ['mileage', 'year']

X = data[features]
print('Predictor Variable is ::\n', X)

#Setting the target variable 

Y = data['price']
print('*' * 80)
print('*' * 80)
print('\n\nTarget Variable is (Price)::\n', Y)
# Out:
# Predictor Variable is ::
#         mileage  year
# 0     274117.0  2008
# 1     190552.0  2011
# 2      39590.0  2018
# 3      64146.0  2014
# 4       6654.0  2018
# ...        ...   ...
# 2494   23609.0  2019
# 2495   34553.0  2018
# 2496   31594.0  2018
# 2497   32557.0  2018
# 2498   31371.0  2018
#
# [2499 rows x 2 columns]
# ********************************************************************************
# ********************************************************************************
#
#
# Target Variable is (Price)::
#  0        6300
# 1        2899
# 2        5350
# 3       25000
# 4       27700
#         ...
# 2494     7800
# 2495     9200
# 2496     9200
# 2497     9200
# 2498     9200
# Name: price, Length: 2499, dtype: int64

# %%
# defining a function that returns and prints the total unique values and its count in that particular column as input

def count_values(x):
    """
    Input:: A column of the dataset passed as dataframe
    Output:: Total count of unique values in that column
    
    """
    values = x.value_counts()
    
    print('Total number of Unique values and its count in the column is:: \n\n', values)
    print()

# %%
# Using count_values funtion to print the unique values in predictor variable

temp1 = data[['year']]
temp1.apply(count_values)
# Out:
# Total number of Unique values and its count in the column is::
#
#  2019    892
# 2018    395
# 2017    377
# 2016    203
# 2015    196
# 2014    104
# 2013     86
# 2012     72
# 2020     48
# 2011     23
# 2008     18
# 2010     13
# 2009     11
# 2003      9
# 2006      8
# 2004      6
# 2005      6
# 2007      6
# 2001      5
# 2000      4
# 1998      4
# 1997      2
# 2002      2
# 1996      2
# 1994      2
# 1999      1
# 1973      1
# 1993      1
# 1995      1
# 1984      1
# Name: year, dtype: int64
# year    None
# dtype: object

# %%
# Using count_values funtion to print the unique values in title status  variable

temp2 = data[['title_status']]
temp2.apply(count_values)
# Out:
# Total number of Unique values and its count in the column is::
#
#  clean vehicle        2336
# salvage insurance     163
# Name: title_status, dtype: int64
# title_status    None
# dtype: object

# %%
# Using count_values funtion to print the unique values in color variable

temp1 = data[['color']]
temp1.apply(count_values)
# Out:
# Total number of Unique values and its count in the column is::
#
#  white                                      707
# black                                      516
# gray                                       395
# silver                                     300
# red                                        192
# blue                                       151
# no_color                                    61
# green                                       24
# orange                                      20
# gold                                        19
# charcoal                                    18
# brown                                       15
# yellow                                       9
# magnetic metallic                            6
# shadow black                                 5
# beige                                        5
# color:                                       5
# ingot silver metallic                        4
# oxford white                                 4
# ...

# %%
# Making a frequency table using categorial variable model

table = data.groupby(['model', 'year', 'brand'])
table.size()
# Out:
# model   year  brand
# 1500    2014  chevrolet     2
#         2015  chevrolet     1
#         2016  chevrolet     7
#         2017  chevrolet    15
#         2018  chevrolet     9
#                            ..
# wagon   2019  ford         18
# x3      2017  bmw           2
# xd      2017  nissan        1
# xt5     2019  cadillac      1
# xterra  2012  nissan        1
# Length: 471, dtype: int64
